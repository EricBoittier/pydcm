# %%
import sys
ars_path = "/home/boittier/pydcm/"
sys.path.insert(1, ars_path)
from _pydcm import *

# %%
# The Gaussian-format cube file containing electron density:
refDensCube="/home/boittier/B.pdb/SCAN_1_2_3_4_S_36_10.0/13_SCAN/B.d.cube"
# The Gaussian-format cube file containing electrostatic potential energy:
refPotCube="/home/boittier/B.pdb/SCAN_1_2_3_4_S_36_10.0/13_SCAN/B.p.cube"
# The root folder for your fitting project
projDir="/home/boittier/pydcm/models/fbutadiene-13"
# The bin directory containing the MDCM scripts and programs
refBinDir="/home/boittier/pydcm/bin"
# The total charge of the molecule to be fitted (a.u.)
qtot=0.0
# The port to use for the local web browser (to view molecules in NGL). Make sure nobody else is using it already!
webPort='8889'
# The name of a Slurm partition allowing jobs to run for up to 2 hours with 4 cores
shortQ='vshort'
longQ='infinite'
# The desired isodensity surface to use for viewing potential energy surfaces (a.u)
isoSurf=0.001


# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Maximum number of charges to fit per atom (minimum is fixed at 1)
maxAChg=4

natm=10
nfrag = 4

minMChg=10
maxMChg=40

# Define fragments using atom numbering from NGL window at top of notebook
frags=[[9, 10, 4],[3,8],[7,2],[5,1,6]]
# Minimum number of charges to fit for each fragment (can average fewer than 1 per atom)
minFChg=[3,2,2,3]
# Maximum number of charges to fit for each fragment (upper limit per atom fixed by maxAChg)
maxFChg=[12,8,8,12]

workdir = projDir + '/'
refdir = workdir + 'ref/'
htmldir = workdir + 'html/'
bindir = refBinDir + '/'
pdbfile = refdir + 'mol.pdb'
densCube = refdir + os.path.basename(refDensCube)
potCube = refdir + os.path.basename(refPotCube)

# %%
pydcm = Pydcm(projDir, refBinDir, refDensCube, refPotCube, webPort, frags, minFChg, maxFChg, maxAChg, minMChg, maxMChg, shortQ, longQ)

# %%
pydcm.make_ref_directory()
pydcm.start_server()
# Out:
# Changed to working directory /home/boittier/pydcm/models/fbutadiene-13/
# 10 atoms in molecule
# writing PDB file /home/boittier/pydcm/models/fbutadiene-13/ref/mol.pdb
#
# Running jobs:python /home/boittier/pydcm/bin/simple-cors-http-server.py 8889
#
# 0 : run_http()
#
# Web server running in directory /home/boittier/pydcm/models/fbutadiene-13, URLs are relative to this path
# If you change the project directory, you need to restart Jupyter-Lab to restart this server and create a new root for URLs

# %%
pydcm.show_ref_models()
# Out:
# ESP range: -0.033346 to 0.033346 a.u.
# 8889 /home/boittier/pydcm/models/fbutadiene-13/html/ /home/boittier/pydcm/models/fbutadiene-13/ref/mol.pdb
# http://localhost:8889/html/refESP.html
#         <iframe
#             width="1120"
#             height="750"
#             src="http://localhost:8889/html/refESP.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.display_mtpfit_comparison()
# Out:
# /home/boittier/pydcm/bin/mtpfit.py
#         <iframe
#             width="1120"
#             height="1550"
#             src="http://localhost:8889/html/mtpFit.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.do_atom_fit(maxAChg, ntry, nfrag)
# Out:
# ## 1Charges Per Atom:
# Atom 1 final RMSE: 3.412858355 kcal/mol
# Atom 2 final RMSE: 1.355518588 kcal/mol
# Atom 3 final RMSE: 4.223162642 kcal/mol
# Atom 4 final RMSE: 2.905356016 kcal/mol
# Atom 5 final RMSE: 1.921599817 kcal/mol
# Atom 6 final RMSE: 1.038562921 kcal/mol
# Atom 7 final RMSE: 1.776676243 kcal/mol
# Atom 8 final RMSE: 1.137781962 kcal/mol
# Atom 9 final RMSE: 1.696227162 kcal/mol
# Atom 10 final RMSE: 0.9999983815 kcal/mol
#
# ## 2Charges Per Atom:
# Atom 1 final RMSE: 1.095174883 kcal/mol
# Atom 2 final RMSE: 1.117409438 kcal/mol
# Atom 3 final RMSE: 0.9660942644 kcal/mol
# Atom 4 final RMSE: 0.9493350046 kcal/mol
# Atom 5 final RMSE: 0.3846940382 kcal/mol
# Atom 6 final RMSE: 0.6164462217 kcal/mol
# Atom 7 final RMSE: 0.8292932567 kcal/mol
# Atom 8 final RMSE: 0.9252561042 kcal/mol
# Atom 9 final RMSE: 0.3888045516 kcal/mol
# Atom 10 final RMSE: 0.8454454374 kcal/mol
#
# ## 3Charges Per Atom:
# Atom 1 final RMSE: 0.2504068792 kcal/mol
# Atom 2 final RMSE: 0.1913323023 kcal/mol
# Atom 3 final RMSE: 0.2340536138 kcal/mol
# Atom 4 final RMSE: 0.1368963911 kcal/mol
# Atom 5 final RMSE: 0.2433521254 kcal/mol
# Atom 6 final RMSE: 0.1747708236 kcal/mol
# Atom 7 final RMSE: 0.5523543258 kcal/mol
# Atom 8 final RMSE: 0.4659205014 kcal/mol
# Atom 9 final RMSE: 0.2203538989 kcal/mol
# Atom 10 final RMSE: 0.3634174885 kcal/mol
#
# ## 4Charges Per Atom:
# Atom 1 final RMSE: 0.06752213137 kcal/mol
# Atom 2 final RMSE: 0.07596932151 kcal/mol
# Atom 3 final RMSE: 0.06924837124 kcal/mol
# Atom 4 final RMSE: 0.09653264076 kcal/mol
# Atom 5 final RMSE: 0.0561974347 kcal/mol
# Atom 6 final RMSE: 0.0687456224 kcal/mol
# Atom 7 final RMSE: 0.08446210196 kcal/mol
# Atom 8 final RMSE: 0.08541361177 kcal/mol
# Atom 9 final RMSE: 0.08861272452 kcal/mol
# Atom 10 final RMSE: 0.1150861643 kcal/mol

# %%
# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Number of separate fits to perform (restarting a fit can lead to a better outcome). Cost scales linearly
nfit=2

pydcm.fit_fragments(ntry, nfit)
# Out:
# Frag 1 fit 1, 10 charges: Job 3483857 is still running
# Frag 1 fit 1, 11 charges: Job 3483858 is still running
# Frag 1 fit 1, 12 charges: Job 3483859 is still running
# Frag 1 fit 1, 13 charges: Job 3483860 is still running
# Frag 1 fit 2, 11 charges: Job 3483868 is still running
# Frag 1 fit 2, 12 charges: Job 3483869 is still running
# Frag 1 fit 2, 13 charges: Job 3483870 is still running
# Frag 4 fit 1, 12 charges: Job 3483907 is still running
# Frag 4 fit 1, 13 charges: Job 3483908 is still running
# Frag 4 fit 2, 12 charges: Job 3483917 is still running
# Frag 4 fit 2, 13 charges: Job 3483918 is still running
#
# Summary of results:
# Frag 1, Fit 1, 3 charges, RMSE: 0.2918164839 kcal/mol
# Frag 1, Fit 1, 4 charges, RMSE: 0.2295051722 kcal/mol
# Frag 1, Fit 1, 5 charges, RMSE: 0.1632077167 kcal/mol
# Frag 1, Fit 1, 6 charges, RMSE: 0.1480951617 kcal/mol
# Frag 1, Fit 1, 7 charges, RMSE: 0.1114232654 kcal/mol
# Frag 1, Fit 1, 8 charges, RMSE: 0.1506029743 kcal/mol
# Frag 1, Fit 2, 3 charges, RMSE: 0.3163281747 kcal/mol
# Frag 1, Fit 2, 4 charges, RMSE: 0.2950521608 kcal/mol
# Frag 1, Fit 2, 5 charges, RMSE: 0.1660852707 kcal/mol
# Frag 1, Fit 2, 6 charges, RMSE: 0.1472968745 kcal/mol
# Frag 1, Fit 2, 7 charges, RMSE: 0.1392003198 kcal/mol
# Frag 1, Fit 2, 8 charges, RMSE: 0.0992287164 kcal/mol
# Frag 1, Fit 2, 9 charges, RMSE: 0.1021329777 kcal/mol
# Frag 2, Fit 1, 2 charges, RMSE: 1.469167237 kcal/mol
# Frag 2, Fit 1, 3 charges, RMSE: 0.3273590976 kcal/mol
# Frag 2, Fit 1, 4 charges, RMSE: 0.1855819985 kcal/mol
# Frag 2, Fit 1, 5 charges, RMSE: 0.1168382525 kcal/mol
# Frag 2, Fit 1, 6 charges, RMSE: 0.07618999686 kcal/mol
# Frag 2, Fit 1, 7 charges, RMSE: 0.05255176317 kcal/mol
# Frag 2, Fit 1, 8 charges, RMSE: 0.05491244121 kcal/mol
# Frag 2, Fit 2, 2 charges, RMSE: 1.469167237 kcal/mol
# Frag 2, Fit 2, 3 charges, RMSE: 0.3694579636 kcal/mol
# Frag 2, Fit 2, 4 charges, RMSE: 0.1855819986 kcal/mol
# Frag 2, Fit 2, 5 charges, RMSE: 0.1222792019 kcal/mol
# Frag 2, Fit 2, 6 charges, RMSE: 0.08172150389 kcal/mol
# Frag 2, Fit 2, 7 charges, RMSE: 0.06335666886 kcal/mol
# Frag 2, Fit 2, 8 charges, RMSE: 0.04611433145 kcal/mol
# Frag 3, Fit 1, 2 charges, RMSE: 0.7522899105 kcal/mol
# Frag 3, Fit 1, 3 charges, RMSE: 0.5545607037 kcal/mol
# Frag 3, Fit 1, 4 charges, RMSE: 0.3157180437 kcal/mol
# Frag 3, Fit 1, 5 charges, RMSE: 0.3088232041 kcal/mol
# Frag 3, Fit 1, 6 charges, RMSE: 0.2570742665 kcal/mol
# Frag 3, Fit 1, 7 charges, RMSE: 0.1596164045 kcal/mol
# Frag 3, Fit 1, 8 charges, RMSE: 0.04291839047 kcal/mol
# Frag 3, Fit 2, 2 charges, RMSE: 0.7522899105 kcal/mol
# Frag 3, Fit 2, 3 charges, RMSE: 0.5545607039 kcal/mol
# Frag 3, Fit 2, 4 charges, RMSE: 0.3157200607 kcal/mol
# Frag 3, Fit 2, 5 charges, RMSE: 0.2729973085 kcal/mol
# Frag 3, Fit 2, 6 charges, RMSE: 0.2535233847 kcal/mol
# Frag 3, Fit 2, 7 charges, RMSE: 0.1020163492 kcal/mol
# Frag 3, Fit 2, 8 charges, RMSE: 0.03967540615 kcal/mol
# Frag 4, Fit 1, 3 charges, RMSE: 0.2625425909 kcal/mol
# Frag 4, Fit 1, 4 charges, RMSE: 0.1907946889 kcal/mol
# Frag 4, Fit 1, 5 charges, RMSE: 0.1295710351 kcal/mol
# Frag 4, Fit 1, 6 charges, RMSE: 0.1222091758 kcal/mol
# Frag 4, Fit 1, 7 charges, RMSE: 0.07800594101 kcal/mol
# Frag 4, Fit 1, 8 charges, RMSE: 0.05819633625 kcal/mol
# Frag 4, Fit 1, 9 charges, RMSE: 0.04828421432 kcal/mol
# Frag 4, Fit 1, 10 charges, RMSE: 0.05102254664 kcal/mol
# Frag 4, Fit 2, 3 charges, RMSE: 0.2625425908 kcal/mol
# Frag 4, Fit 2, 4 charges, RMSE: 0.1907946933 kcal/mol
# Frag 4, Fit 2, 5 charges, RMSE: 0.20711095 kcal/mol
# Frag 4, Fit 2, 6 charges, RMSE: 0.1007740565 kcal/mol
# Frag 4, Fit 2, 7 charges, RMSE: 0.09314402482 kcal/mol
# Frag 4, Fit 2, 8 charges, RMSE: 0.05727893474 kcal/mol
# Frag 4, Fit 2, 9 charges, RMSE: 0.04509295377 kcal/mol
# Frag 4, Fit 2, 10 charges, RMSE: 0.03735629454 kcal/mol

# %%
pydcm.combine_fragements(ntry, nfit)
# Out:
# 10 CHARGES:
# NEW BEST 10 charges: 3 2 2 3 rmse = 0.6939540555499999
# 11 CHARGES:
# NEW BEST 11 charges: 3 2 2 4 rmse = 0.6760170800749999
# NEW BEST 11 charges: 3 2 3 3 rmse = 0.6445217538499999
# NEW BEST 11 charges: 3 3 2 3 rmse = 0.40850202069999997
# 12 CHARGES:
# NEW BEST 12 charges: 3 2 2 5 rmse = 0.660711166625
# NEW BEST 12 charges: 3 2 3 4 rmse = 0.6265847783749999
# NEW BEST 12 charges: 3 2 4 3 rmse = 0.58481108885
# NEW BEST 12 charges: 3 3 2 4 rmse = 0.390565045225
# NEW BEST 12 charges: 3 3 3 3 rmse = 0.35906971899999995
# 13 CHARGES:
# NEW BEST 13 charges: 3 2 2 6 rmse = 0.653511921975
# NEW BEST 13 charges: 3 2 3 5 rmse = 0.6112788649249999
# NEW BEST 13 charges: 3 2 4 4 rmse = 0.566874113375
# NEW BEST 13 charges: 3 3 2 5 rmse = 0.37525913177500003
# NEW BEST 13 charges: 3 3 3 4 rmse = 0.341132743525
# NEW BEST 13 charges: 3 3 4 3 rmse = 0.29935905399999996
# 14 CHARGES:
# NEW BEST 14 charges: 3 2 2 7 rmse = 0.6478198931024999
# NEW BEST 14 charges: 3 2 3 6 rmse = 0.604079620275
# NEW BEST 14 charges: 3 2 4 5 rmse = 0.5515681999250001
# NEW BEST 14 charges: 3 3 2 6 rmse = 0.368059887125
# NEW BEST 14 charges: 3 3 3 5 rmse = 0.325826830075
# NEW BEST 14 charges: 3 3 4 4 rmse = 0.281422078525
# NEW BEST 14 charges: 3 4 4 3 rmse = 0.26391477922499995
# 15 CHARGES:
# NEW BEST 15 charges: 3 2 2 8 rmse = 0.6426381415349999
# NEW BEST 15 charges: 3 2 3 7 rmse = 0.5983875914024999
# NEW BEST 15 charges: 3 2 4 6 rmse = 0.5443689552750001
# NEW BEST 15 charges: 3 2 5 5 rmse = 0.540888016125
# NEW BEST 15 charges: 3 2 7 3 rmse = 0.531385665225
# NEW BEST 15 charges: 3 3 2 7 rmse = 0.3623678582525
# NEW BEST 15 charges: 3 3 3 6 rmse = 0.31862758542499997
# NEW BEST 15 charges: 3 3 4 5 rmse = 0.266116165075
# NEW BEST 15 charges: 3 4 4 4 rmse = 0.24597780375
# 16 CHARGES:
# NEW BEST 16 charges: 3 2 2 9 rmse = 0.6395916462925
# NEW BEST 16 charges: 3 2 3 8 rmse = 0.5932058398349999
# NEW BEST 16 charges: 3 2 4 7 rmse = 0.5386769264025
# NEW BEST 16 charges: 3 2 5 6 rmse = 0.533688771475
# NEW BEST 16 charges: 3 2 7 4 rmse = 0.5134486897499999
# NEW BEST 16 charges: 3 3 2 8 rmse = 0.357186106685
# NEW BEST 16 charges: 3 3 3 7 rmse = 0.3129355565525
# NEW BEST 16 charges: 3 3 4 6 rmse = 0.258916920425
# NEW BEST 16 charges: 3 3 5 5 rmse = 0.255435981275
# NEW BEST 16 charges: 3 3 7 3 rmse = 0.245933630375
# NEW BEST 16 charges: 3 4 4 5 rmse = 0.2306718903
# NEW BEST 16 charges: 3 5 4 4 rmse = 0.22879186725
# 17 CHARGES:
# NEW BEST 17 charges: 3 2 2 10 rmse = 0.6376574814849999
# NEW BEST 17 charges: 3 2 3 9 rmse = 0.5901593445925
# NEW BEST 17 charges: 3 2 4 8 rmse = 0.533495174835
# NEW BEST 17 charges: 3 2 5 7 rmse = 0.5279967426025
# NEW BEST 17 charges: 3 2 7 5 rmse = 0.4981427762999999
# NEW BEST 17 charges: 3 2 8 4 rmse = 0.4978634539875
# NEW BEST 17 charges: 3 3 2 9 rmse = 0.3541396114425
# NEW BEST 17 charges: 3 3 3 8 rmse = 0.307753804985
# NEW BEST 17 charges: 3 3 4 7 rmse = 0.2532248915525
# NEW BEST 17 charges: 3 3 5 6 rmse = 0.24823673662499998
# NEW BEST 17 charges: 3 3 7 4 rmse = 0.22799665489999998
# NEW BEST 17 charges: 3 4 4 6 rmse = 0.22347264565
# NEW BEST 17 charges: 3 4 5 5 rmse = 0.2199917065
# NEW BEST 17 charges: 3 4 7 3 rmse = 0.21048935559999998
# 18 CHARGES:
# NEW BEST 18 charges: 3 2 2 11 rmse = 25000.37831840785
# NEW BEST 18 charges: 3 2 3 10 rmse = 0.5882251797849999
# NEW BEST 18 charges: 3 2 4 9 rmse = 0.5304486795925001
# NEW BEST 18 charges: 3 2 5 8 rmse = 0.522814991035
# NEW BEST 18 charges: 3 2 7 6 rmse = 0.49094353164999993
# NEW BEST 18 charges: 3 2 8 5 rmse = 0.4825575405375
# NEW BEST 18 charges: 3 3 2 10 rmse = 0.352205446635
# NEW BEST 18 charges: 3 3 3 9 rmse = 0.3047073097425
# NEW BEST 18 charges: 3 3 4 8 rmse = 0.248043139985
# NEW BEST 18 charges: 3 3 5 7 rmse = 0.24254470775249998
# NEW BEST 18 charges: 3 3 7 5 rmse = 0.21269074145
# NEW BEST 18 charges: 3 3 8 4 rmse = 0.2124114191375
# NEW BEST 18 charges: 3 4 7 4 rmse = 0.19255238012499998
# 19 CHARGES:
# NEW BEST 19 charges: 3 2 2 12 rmse = 25000.37831840785
# NEW BEST 19 charges: 3 2 3 11 rmse = 25000.32888610615
# NEW BEST 19 charges: 3 2 4 10 rmse = 0.528514514785
# NEW BEST 19 charges: 3 2 5 9 rmse = 0.5197684957925
# NEW BEST 19 charges: 3 2 6 8 rmse = 0.5179465100849999
# NEW BEST 19 charges: 3 2 7 7 rmse = 0.48525150277749995
# NEW BEST 19 charges: 3 2 8 6 rmse = 0.47535829588749995
# NEW BEST 19 charges: 3 3 3 10 rmse = 0.30277314493499996
# NEW BEST 19 charges: 3 3 4 9 rmse = 0.2449966447425
# NEW BEST 19 charges: 3 3 5 8 rmse = 0.23736295618499997
# NEW BEST 19 charges: 3 3 7 6 rmse = 0.2054914968
# NEW BEST 19 charges: 3 3 8 5 rmse = 0.1971055056875
# NEW BEST 19 charges: 3 4 7 5 rmse = 0.177246466675
# NEW BEST 19 charges: 3 4 8 4 rmse = 0.1769671443625
# NEW BEST 19 charges: 3 5 7 4 rmse = 0.17536644362499998
# 20 CHARGES:
# NEW BEST 20 charges: 3 2 3 12 rmse = 25000.32888610615
# NEW BEST 20 charges: 3 2 4 11 rmse = 25000.26917544115
# NEW BEST 20 charges: 3 2 5 10 rmse = 0.517834330985
# NEW BEST 20 charges: 3 2 6 9 rmse = 0.5149000148425
# NEW BEST 20 charges: 3 2 7 8 rmse = 0.48006975120999995
# NEW BEST 20 charges: 3 2 8 7 rmse = 0.46966626701499997
# NEW BEST 20 charges: 3 3 4 10 rmse = 0.243062479935
# NEW BEST 20 charges: 3 3 5 9 rmse = 0.23431646094249997
# NEW BEST 20 charges: 3 3 6 8 rmse = 0.232494475235
# NEW BEST 20 charges: 3 3 7 7 rmse = 0.1997994679275
# NEW BEST 20 charges: 3 3 8 6 rmse = 0.1899062610375
# NEW BEST 20 charges: 3 4 7 6 rmse = 0.170047222025
# NEW BEST 20 charges: 3 4 8 5 rmse = 0.1616612309125
# NEW BEST 20 charges: 3 5 7 5 rmse = 0.160060530175
# NEW BEST 20 charges: 3 5 8 4 rmse = 0.1597812078625
# 21 CHARGES:
# NEW BEST 21 charges: 3 2 4 12 rmse = 25000.26917544115
# NEW BEST 21 charges: 3 2 5 11 rmse = 25000.25849525735
# NEW BEST 21 charges: 3 2 6 10 rmse = 0.512965850035
# NEW BEST 21 charges: 3 2 7 9 rmse = 0.47702325596749995
# NEW BEST 21 charges: 3 2 8 8 rmse = 0.46448451544749997
# NEW BEST 21 charges: 3 3 5 10 rmse = 0.23238229613499997
# NEW BEST 21 charges: 3 3 6 9 rmse = 0.2294479799925
# NEW BEST 21 charges: 3 3 7 8 rmse = 0.19461771636
# NEW BEST 21 charges: 3 3 8 7 rmse = 0.184214232165
# NEW BEST 21 charges: 3 4 7 7 rmse = 0.1643551931525
# NEW BEST 21 charges: 3 4 8 6 rmse = 0.15446198626250002
# NEW BEST 21 charges: 3 5 7 6 rmse = 0.152861285525
# NEW BEST 21 charges: 3 5 8 5 rmse = 0.1444752944125
# NEW BEST 21 charges: 4 5 8 4 rmse = 0.1442033799375
# NEW BEST 21 charges: 5 5 7 4 rmse = 0.14321425182500003
# 22 CHARGES:
# NEW BEST 22 charges: 3 2 5 12 rmse = 25000.25849525735
# NEW BEST 22 charges: 3 2 6 11 rmse = 25000.2536267764
# NEW BEST 22 charges: 3 2 7 10 rmse = 0.47508909116
# NEW BEST 22 charges: 3 2 8 9 rmse = 0.46143802020499997
# NEW BEST 22 charges: 3 3 6 10 rmse = 0.227513815185
# NEW BEST 22 charges: 3 3 7 9 rmse = 0.1915712211175
# NEW BEST 22 charges: 3 3 8 8 rmse = 0.1790324805975
# NEW BEST 22 charges: 3 4 7 8 rmse = 0.159173441585
# NEW BEST 22 charges: 3 4 8 7 rmse = 0.14876995739
# NEW BEST 22 charges: 3 5 7 7 rmse = 0.1471692566525
# NEW BEST 22 charges: 3 5 8 6 rmse = 0.1372760497625
# NEW BEST 22 charges: 3 6 8 5 rmse = 0.1343132305025
# NEW BEST 22 charges: 4 5 8 5 rmse = 0.1288974664875
# NEW BEST 22 charges: 5 5 7 5 rmse = 0.127908338375
# NEW BEST 22 charges: 5 5 8 4 rmse = 0.1276290160625
# 23 CHARGES:
# NEW BEST 23 charges: 3 2 6 12 rmse = 25000.2536267764
# NEW BEST 23 charges: 3 2 7 11 rmse = 25000.215750017524
# NEW BEST 23 charges: 3 2 8 10 rmse = 0.45950385539749994
# NEW BEST 23 charges: 3 3 7 10 rmse = 0.18963705631
# NEW BEST 23 charges: 3 3 8 9 rmse = 0.17598598535499999
# NEW BEST 23 charges: 3 4 7 9 rmse = 0.1561269463425
# NEW BEST 23 charges: 3 4 8 8 rmse = 0.1435882058225
# NEW BEST 23 charges: 3 5 7 8 rmse = 0.141987505085
# NEW BEST 23 charges: 3 5 8 7 rmse = 0.13158402089
# NEW BEST 23 charges: 3 6 8 6 rmse = 0.1271139858525
# NEW BEST 23 charges: 4 5 8 6 rmse = 0.1216982218375
# NEW BEST 23 charges: 4 6 8 5 rmse = 0.1187354025775
# NEW BEST 23 charges: 5 5 8 5 rmse = 0.1123231026125
# 24 CHARGES:
# NEW BEST 24 charges: 3 2 7 12 rmse = 25000.215750017524
# NEW BEST 24 charges: 3 2 8 11 rmse = 25000.200164781763
# NEW BEST 24 charges: 3 3 6 12 rmse = 24999.96817474155
# NEW BEST 24 charges: 3 3 7 11 rmse = 24999.930297982675
# NEW BEST 24 charges: 3 3 8 10 rmse = 0.17405182054749999
# NEW BEST 24 charges: 3 4 7 10 rmse = 0.154192781535
# NEW BEST 24 charges: 3 4 8 9 rmse = 0.14054171058
# NEW BEST 24 charges: 3 5 7 9 rmse = 0.1389410098425
# NEW BEST 24 charges: 3 5 8 8 rmse = 0.12640226932249998
# NEW BEST 24 charges: 3 6 8 7 rmse = 0.12142195698
# NEW BEST 24 charges: 3 7 8 6 rmse = 0.12120442742999998
# NEW BEST 24 charges: 4 5 8 7 rmse = 0.116006192965
# NEW BEST 24 charges: 4 6 8 6 rmse = 0.11153615792749999
# NEW BEST 24 charges: 5 5 8 6 rmse = 0.1051238579625
# NEW BEST 24 charges: 5 6 8 5 rmse = 0.1021610387025
# 25 CHARGES:
# NEW BEST 25 charges: 3 2 8 12 rmse = 25000.200164781763
# NEW BEST 25 charges: 3 3 7 12 rmse = 24999.930297982675
# NEW BEST 25 charges: 3 3 8 11 rmse = 24999.91471274691
# NEW BEST 25 charges: 3 4 7 11 rmse = 24999.8948537079
# NEW BEST 25 charges: 3 4 8 10 rmse = 0.1386075457725
# NEW BEST 25 charges: 3 5 7 10 rmse = 0.137006845035
# NEW BEST 25 charges: 3 5 8 9 rmse = 0.12335577408
# NEW BEST 25 charges: 3 6 8 8 rmse = 0.11624020541249999
# NEW BEST 25 charges: 3 7 8 7 rmse = 0.11551239855749998
# NEW BEST 25 charges: 4 5 8 8 rmse = 0.1108244413975
# NEW BEST 25 charges: 4 6 8 7 rmse = 0.10584412905499999
# NEW BEST 25 charges: 4 7 8 6 rmse = 0.10562659950499999
# NEW BEST 25 charges: 5 5 8 7 rmse = 0.09943182909
# NEW BEST 25 charges: 5 6 8 6 rmse = 0.09496179405249999
# 26 CHARGES:
# NEW BEST 26 charges: 3 3 8 12 rmse = 24999.91471274691
# NEW BEST 26 charges: 3 4 7 12 rmse = 24999.8948537079
# NEW BEST 26 charges: 3 4 8 11 rmse = 24999.879268472137
# NEW BEST 26 charges: 3 5 7 11 rmse = 24999.8776677714
# NEW BEST 26 charges: 3 5 8 10 rmse = 0.1214216092725
# NEW BEST 26 charges: 3 6 8 9 rmse = 0.11319371016999999
# NEW BEST 26 charges: 3 7 8 8 rmse = 0.11033064698999999
# NEW BEST 26 charges: 4 5 8 9 rmse = 0.107777946155
# NEW BEST 26 charges: 4 6 8 8 rmse = 0.1006623774875
# NEW BEST 26 charges: 4 7 8 7 rmse = 0.0999345706325
# NEW BEST 26 charges: 5 5 8 8 rmse = 0.0942500775225
# NEW BEST 26 charges: 5 6 8 7 rmse = 0.08926976517999999
# NEW BEST 26 charges: 5 7 8 6 rmse = 0.08905223562999999
# 27 CHARGES:
# NEW BEST 27 charges: 3 4 8 12 rmse = 24999.879268472137
# NEW BEST 27 charges: 3 5 7 12 rmse = 24999.8776677714
# NEW BEST 27 charges: 3 5 8 11 rmse = 24999.862082535637
# NEW BEST 27 charges: 3 6 8 10 rmse = 0.11125954536249999
# NEW BEST 27 charges: 3 7 8 9 rmse = 0.10728415174749999
# NEW BEST 27 charges: 4 5 8 10 rmse = 0.1058437813475
# NEW BEST 27 charges: 4 6 8 9 rmse = 0.097615882245
# NEW BEST 27 charges: 4 7 8 8 rmse = 0.094752819065
# NEW BEST 27 charges: 5 5 8 9 rmse = 0.09120358228
# NEW BEST 27 charges: 5 6 8 8 rmse = 0.0840880136125
# NEW BEST 27 charges: 5 7 8 7 rmse = 0.0833602067575
# NEW BEST 27 charges: 7 6 8 6 rmse = 0.0820156812275
# 28 CHARGES:
# NEW BEST 28 charges: 3 5 8 12 rmse = 24999.862082535637
# NEW BEST 28 charges: 3 6 8 11 rmse = 24999.851920471727
# NEW BEST 28 charges: 3 7 8 10 rmse = 0.10534998693999999
# NEW BEST 28 charges: 4 6 8 10 rmse = 0.0956817174375
# NEW BEST 28 charges: 4 7 8 9 rmse = 0.09170632382249999
# NEW BEST 28 charges: 5 5 8 10 rmse = 0.0892694174725
# NEW BEST 28 charges: 5 6 8 9 rmse = 0.08104151837
# NEW BEST 28 charges: 5 7 8 8 rmse = 0.07817845519
# NEW BEST 28 charges: 7 6 8 7 rmse = 0.076323652355
# NEW BEST 28 charges: 7 7 8 6 rmse = 0.07610612280500001
# 29 CHARGES:
# NEW BEST 29 charges: 3 6 8 12 rmse = 24999.851920471727
# NEW BEST 29 charges: 3 7 8 11 rmse = 24999.846010913305
# NEW BEST 29 charges: 3 8 8 10 rmse = 0.10374062900999999
# NEW BEST 29 charges: 4 7 8 10 rmse = 0.08977215901499999
# NEW BEST 29 charges: 5 6 8 10 rmse = 0.0791073535625
# NEW BEST 29 charges: 5 7 8 9 rmse = 0.0751319599475
# NEW BEST 29 charges: 6 7 8 8 rmse = 0.07420074464
# NEW BEST 29 charges: 7 6 8 8 rmse = 0.0711419007875
# NEW BEST 29 charges: 7 7 8 7 rmse = 0.0704140939325
# 30 CHARGES:
# NEW BEST 30 charges: 3 7 8 12 rmse = 24999.846010913305
# NEW BEST 30 charges: 3 8 8 11 rmse = 24999.844401555376
# NEW BEST 30 charges: 4 6 8 12 rmse = 24999.8363426438
# NEW BEST 30 charges: 4 7 8 11 rmse = 24999.83043308538
# NEW BEST 30 charges: 4 8 8 10 rmse = 0.08816280108499999
# NEW BEST 30 charges: 5 7 8 10 rmse = 0.07319779514
# NEW BEST 30 charges: 6 7 8 9 rmse = 0.07115424939750001
# NEW BEST 30 charges: 7 6 8 9 rmse = 0.068095405545
# NEW BEST 30 charges: 7 7 8 8 rmse = 0.065232342365
# 31 CHARGES:
# NEW BEST 31 charges: 3 8 8 12 rmse = 24999.844401555376
# NEW BEST 31 charges: 4 7 8 12 rmse = 24999.83043308538
# NEW BEST 31 charges: 4 8 8 11 rmse = 24999.82882372745
# NEW BEST 31 charges: 5 6 8 12 rmse = 24999.81976827993
# NEW BEST 31 charges: 5 7 8 11 rmse = 24999.813858721503
# NEW BEST 31 charges: 5 8 8 10 rmse = 0.07158843721
# NEW BEST 31 charges: 6 7 8 10 rmse = 0.06922008459000001
# NEW BEST 31 charges: 7 6 8 10 rmse = 0.0661612407375
# NEW BEST 31 charges: 7 7 8 9 rmse = 0.062185847122500006
# NEW BEST 31 charges: 8 7 8 8 rmse = 0.06218370511500001
# 32 CHARGES:
# NEW BEST 32 charges: 4 8 8 12 rmse = 24999.82882372745
# NEW BEST 32 charges: 5 7 8 12 rmse = 24999.813858721503
# NEW BEST 32 charges: 5 8 8 11 rmse = 24999.812249363575
# NEW BEST 32 charges: 6 7 8 11 rmse = 24999.809881010955
# NEW BEST 32 charges: 6 8 8 10 rmse = 0.06761072666000001
# NEW BEST 32 charges: 7 7 8 10 rmse = 0.060251682315000006
# NEW BEST 32 charges: 8 7 8 9 rmse = 0.059137209872500006
# 33 CHARGES:
# NEW BEST 33 charges: 5 8 8 12 rmse = 24999.812249363575
# NEW BEST 33 charges: 6 7 8 12 rmse = 24999.809881010955
# NEW BEST 33 charges: 6 8 8 11 rmse = 24999.808271653026
# NEW BEST 33 charges: 7 6 8 12 rmse = 24999.806822167102
# NEW BEST 33 charges: 7 7 8 11 rmse = 24999.80091260868
# NEW BEST 33 charges: 7 8 8 10 rmse = 0.058642324385
# NEW BEST 33 charges: 8 7 8 10 rmse = 0.057203045065000006
# 34 CHARGES:
# NEW BEST 34 charges: 6 8 8 12 rmse = 24999.808271653026
# NEW BEST 34 charges: 7 7 8 12 rmse = 24999.80091260868
# NEW BEST 34 charges: 7 8 8 11 rmse = 24999.79930325075
# NEW BEST 34 charges: 8 7 8 11 rmse = 24999.79786397143
# NEW BEST 34 charges: 8 8 8 10 rmse = 0.055593687135
# 35 CHARGES:
# NEW BEST 35 charges: 7 8 8 12 rmse = 24999.79930325075
# NEW BEST 35 charges: 8 7 8 12 rmse = 24999.79786397143
# NEW BEST 35 charges: 8 8 8 11 rmse = 24999.7962546135
# NEW BEST 35 charges: 9 8 8 10 rmse = 0.056319752460000004
# 36 CHARGES:
# NEW BEST 36 charges: 8 8 8 12 rmse = 24999.7962546135
# NEW BEST 36 charges: 10 8 8 10 rmse = 24999.780786508036
# 37 CHARGES:
# NEW BEST 37 charges: 9 8 8 12 rmse = 24999.796980678824
# NEW BEST 37 charges: 11 8 8 10 rmse = 24999.780786508036
# 38 CHARGES:
# NEW BEST 38 charges: 10 8 8 12 rmse = 49999.521447434396
# NEW BEST 38 charges: 12 8 8 10 rmse = 24999.780786508036
# 39 CHARGES:
# NEW BEST 39 charges: 11 8 8 12 rmse = 49999.521447434396
# 40 CHARGES:
# NEW BEST 40 charges: 12 8 8 12 rmse = 49999.521447434396

# %%
pydcm.refine_models()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-efadda83fb7c> in <module>
# ----> 1 pydcm.refine_models()
#
# ~/pydcm/_pydcm.py in refine_models(self, MINNTRY, MAXNTRY)
#    1069                 # case 2: output exists and job has finished or crashed
#    1070                 if os.path.isfile(subdir + str(i) + '-charges.sh') and status == 0:
# -> 1071                     sf = open(subdir + str(i) + '-charges.out', 'r')
#    1072                     for line in sf.readlines():
#    1073                         a = line.split()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/boittier/pydcm/models/fbutadiene-13/5-refine/16-charges/16-charges.out'
