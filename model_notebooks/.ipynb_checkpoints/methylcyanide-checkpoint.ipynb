# %%
import sys
ars_path = "/home/boittier/pydcm/"
sys.path.insert(1, ars_path)
from _pydcm import *

# %%
__name = "methylcyanide"

# The Gaussian-format cube file containing electron density:
refDensCube=f"/home/boittier/test_systems/{__name}/{__name}.chk.d.cube"
# The Gaussian-format cube file containing electrostatic potential energy:
refPotCube=f"/home/boittier/test_systems/{__name}/{__name}.chk.p.cube"
# The root folder for your fitting project
projDir=f"/home/boittier/pydcm/models/{__name}"
# The bin directory containing the MDCM scripts and programs
refBinDir="/home/boittier/pydcm/bin"
# The total charge of the molecule to be fitted (a.u.)
qtot=0.0
# The port to use for the local web browser (to view molecules in NGL). Make sure nobody else is using it already!
webPort='8888'
# The name of a Slurm partition allowing jobs to run for up to 2 hours with 4 cores
shortQ='short'
longQ='long'
# The desired isodensity surface to use for viewing potential energy surfaces (a.u)
isoSurf=0.001


# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=1
# Maximum number of charges to fit per atom (minimum is fixed at 1)
maxAChg=2

natm=6
nfrag = 1

minMChg=6
maxMChg=12

# Define fragments using atom numbering from NGL window at top of notebook
frags= [[1, 2,3,4,5,6] ]
# Minimum number of charges to fit for each fragment (can average fewer than 1 per atom)
minFChg=[6]
# Maximum number of charges to fit for each fragment (upper limit per atom fixed by maxAChg)
maxFChg=[12]

workdir = projDir + '/'
refdir = workdir + 'ref/'
htmldir = workdir + 'html/'
bindir = refBinDir + '/'
pdbfile = refdir + 'mol.pdb'
densCube = refdir + os.path.basename(refDensCube)
potCube = refdir + os.path.basename(refPotCube)

# %%
pydcm = Pydcm(projDir, refBinDir, refDensCube, refPotCube, webPort, frags, minFChg, maxFChg, maxAChg, minMChg, maxMChg, shortQ, longQ)

# %%
pydcm.make_ref_directory()
pydcm.start_server()
# Out:
# Changed to working directory /home/boittier/pydcm/models/methylcyanide/
# 6 atoms in molecule
# writing PDB file /home/boittier/pydcm/models/methylcyanide/ref/mol.pdb
#
# Running jobs:
# 0 : run_http()
#
# python /home/boittier/pydcm/bin/simple-cors-http-server.py 8888Web server running in directory /home/boittier/pydcm/models/methylcyanide, URLs are relative to this path
# If you change the project directory, you need to restart Jupyter-Lab to restart this server and create a new root for URLs
# Traceback (most recent call last):
#   File "/home/boittier/pydcm/bin/simple-cors-http-server.py", line 11, in <module>
#     test(CORSRequestHandler, HTTPServer, port=int(sys.argv[1]) if len(sys.argv) > 1 else 8000)
#   File "/home/boittier/miniconda3/lib/python3.8/http/server.py", line 1249, in test
#     with ServerClass(addr, HandlerClass) as httpd:
#   File "/home/boittier/miniconda3/lib/python3.8/socketserver.py", line 452, in __init__
#     self.server_bind()
#   File "/home/boittier/miniconda3/lib/python3.8/http/server.py", line 138, in server_bind
#     socketserver.TCPServer.server_bind(self)
#   File "/home/boittier/miniconda3/lib/python3.8/socketserver.py", line 466, in server_bind
#     self.socket.bind(self.server_address)
# OSError: [Errno 98] Address already in use

# %%
pydcm.show_ref_models()
# Out:
# ESP range: -0.0612619 to 0.0612619 a.u.
# 8888 /home/boittier/pydcm/models/methylcyanide/html/ /home/boittier/pydcm/models/methylcyanide/ref/mol.pdb
# http://localhost:8888/html/refESP.html
#         <iframe
#             width="1120"
#             height="750"
#             src="http://localhost:8888/html/refESP.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.display_mtpfit_comparison()
# Out:
# /home/boittier/pydcm/bin/mtpfit.py
#         <iframe
#             width="1120"
#             height="1550"
#             src="http://localhost:8888/html/mtpFit.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.do_atom_fit(maxAChg, ntry, nfrag)
# Out:
# submitted jobID 636685
# submitted jobID 636686
# submitted jobID 636687
# submitted jobID 636688
# submitted jobID 636689
# submitted jobID 636690
#
# ## 1Charges Per Atom:
# Atom 1 final RMSE: 0 kcal/mol
# Atom 2 final RMSE: 0 kcal/mol
# Atom 3 final RMSE: 0 kcal/mol
# Atom 4 final RMSE: 0 kcal/mol
# Atom 5 final RMSE: 0 kcal/mol
# Atom 6 final RMSE: 0 kcal/mol
#
# ## 2Charges Per Atom:
# Atom 1 final RMSE: 0 kcal/mol
# Atom 2 final RMSE: 0 kcal/mol
# Atom 3 final RMSE: 0 kcal/mol
# Atom 4 final RMSE: 0 kcal/mol
# Atom 5 final RMSE: 0 kcal/mol
# Atom 6 final RMSE: 0 kcal/mol

# %%
# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=1
# Number of separate fits to perform (restarting a fit can lead to a better outcome). Cost scales linearly
nfit=1

pydcm.fit_fragments(ntry, nfit)
# Out:
# Summary of results:
# Frag 1, Fit 1, 3 charges, RMSE: 0.9402534442 kcal/mol
# Frag 1, Fit 1, 4 charges, RMSE: 0.6458818301 kcal/mol
# Frag 1, Fit 1, 5 charges, RMSE: 0.5831753507 kcal/mol
# Frag 1, Fit 1, 6 charges, RMSE: 0.4677275081 kcal/mol
# Frag 1, Fit 1, 7 charges, RMSE: 0.1827064671 kcal/mol
# Frag 1, Fit 1, 8 charges, RMSE: 0.1525797004 kcal/mol
# Frag 1, Fit 1, 9 charges, RMSE: 0.1417617916 kcal/mol
# Frag 1, Fit 1, 10 charges, RMSE: 0.1311361361 kcal/mol
# Frag 1, Fit 1, 11 charges, RMSE: 0.1102166945 kcal/mol
# Frag 1, Fit 1, 12 charges, RMSE: 0.1123458203 kcal/mol
# Frag 1, Fit 2, 3 charges, RMSE: 0.9402534446 kcal/mol
# Frag 1, Fit 2, 4 charges, RMSE: 0.6499527882 kcal/mol
# Frag 1, Fit 2, 5 charges, RMSE: 0.3123857272 kcal/mol
# Frag 1, Fit 2, 6 charges, RMSE: 0.2874867399 kcal/mol
# Frag 1, Fit 2, 7 charges, RMSE: 0.2247355793 kcal/mol
# Frag 1, Fit 2, 8 charges, RMSE: 0.2063043874 kcal/mol
# Frag 1, Fit 2, 9 charges, RMSE: 0.1797089353 kcal/mol
# Frag 1, Fit 2, 10 charges, RMSE: 0.1278776617 kcal/mol
# Frag 1, Fit 2, 11 charges, RMSE: 0.1316042243 kcal/mol
# Frag 1, Fit 2, 12 charges, RMSE: 0.1160768193 kcal/mol
# Frag 2, Fit 1, 2 charges, RMSE: 0.8599078271 kcal/mol
# Frag 2, Fit 1, 3 charges, RMSE: 0.5202878995 kcal/mol
# Frag 2, Fit 1, 4 charges, RMSE: 0.1254590097 kcal/mol
# Frag 2, Fit 1, 5 charges, RMSE: 0.08230524052 kcal/mol
# Frag 2, Fit 1, 6 charges, RMSE: 0.0527822026 kcal/mol
# Frag 2, Fit 1, 7 charges, RMSE: 0.05144832829 kcal/mol
# Frag 2, Fit 1, 8 charges, RMSE: 0.03905835466 kcal/mol
# Frag 2, Fit 2, 2 charges, RMSE: 0.8599078271 kcal/mol
# Frag 2, Fit 2, 3 charges, RMSE: 0.5202878998 kcal/mol
# Frag 2, Fit 2, 4 charges, RMSE: 0.1254590094 kcal/mol
# Frag 2, Fit 2, 5 charges, RMSE: 0.0745122156 kcal/mol
# Frag 2, Fit 2, 6 charges, RMSE: 0.05193205062 kcal/mol
# Frag 2, Fit 2, 7 charges, RMSE: 0.05188814086 kcal/mol
# Frag 2, Fit 2, 8 charges, RMSE: 0.04539037044 kcal/mol
# Frag 3, Fit 1, 2 charges, RMSE: 2.36956213 kcal/mol
# Frag 3, Fit 1, 3 charges, RMSE: 0.991233574 kcal/mol
# Frag 3, Fit 1, 4 charges, RMSE: 0.3227584302 kcal/mol
# Frag 3, Fit 1, 5 charges, RMSE: 0.09879598057 kcal/mol
# Frag 3, Fit 1, 6 charges, RMSE: 0.08585998582 kcal/mol
# Frag 3, Fit 1, 7 charges, RMSE: 0.0359030012 kcal/mol
# Frag 3, Fit 1, 8 charges, RMSE: 0.08850177553 kcal/mol
# Frag 3, Fit 2, 2 charges, RMSE: 2.36956213 kcal/mol
# Frag 3, Fit 2, 3 charges, RMSE: 0.9912335729 kcal/mol
# Frag 3, Fit 2, 4 charges, RMSE: 0.3227584276 kcal/mol
# Frag 3, Fit 2, 5 charges, RMSE: 0.09871655971 kcal/mol
# Frag 3, Fit 2, 6 charges, RMSE: 0.08504136702 kcal/mol
# Frag 3, Fit 2, 7 charges, RMSE: 0.08724332694 kcal/mol
# Frag 3, Fit 2, 8 charges, RMSE: 0.08522195271 kcal/mol
# Frag 4, Fit 1, 3 charges, RMSE: 0.809007694 kcal/mol
# Frag 4, Fit 1, 4 charges, RMSE: 0.6191441075 kcal/mol
# Frag 4, Fit 1, 5 charges, RMSE: 0.3635530482 kcal/mol
# Frag 4, Fit 1, 6 charges, RMSE: 0.2274489846 kcal/mol
# Frag 4, Fit 1, 7 charges, RMSE: 0.1521378024 kcal/mol
# Frag 4, Fit 1, 8 charges, RMSE: 0.2173646325 kcal/mol
# Frag 4, Fit 1, 9 charges, RMSE: 0.1657858533 kcal/mol
# Frag 4, Fit 1, 10 charges, RMSE: 0.1370601167 kcal/mol
# Frag 4, Fit 1, 11 charges, RMSE: 0.1183992742 kcal/mol
# Frag 4, Fit 1, 12 charges, RMSE: 0.08537721577 kcal/mol
# Frag 4, Fit 2, 3 charges, RMSE: 0.7209390517 kcal/mol
# Frag 4, Fit 2, 4 charges, RMSE: 0.564137602 kcal/mol
# Frag 4, Fit 2, 5 charges, RMSE: 0.3637721119 kcal/mol
# Frag 4, Fit 2, 6 charges, RMSE: 0.213131429 kcal/mol
# Frag 4, Fit 2, 7 charges, RMSE: 0.2051922697 kcal/mol
# Frag 4, Fit 2, 8 charges, RMSE: 0.2275259883 kcal/mol
# Frag 4, Fit 2, 9 charges, RMSE: 0.1435288761 kcal/mol
# Frag 4, Fit 2, 10 charges, RMSE: 0.1688722237 kcal/mol
# Frag 4, Fit 2, 11 charges, RMSE: 0.123343834 kcal/mol
# Frag 4, Fit 2, 12 charges, RMSE: 0.1062329275 kcal/mol

# %%
pydcm.combine_fragements(ntry, nfit)
# Out:
# 10 CHARGES:
# NEW BEST 10 charges: 3 2 2 3 rmse = 1.22266561325
# 11 CHARGES:
# NEW BEST 11 charges: 3 2 2 4 rmse = 1.1834652508249999
# NEW BEST 11 charges: 3 2 3 3 rmse = 0.8780834739750001
# 12 CHARGES:
# NEW BEST 12 charges: 3 2 2 5 rmse = 1.133319112375
# NEW BEST 12 charges: 3 2 3 4 rmse = 0.83888311155
# NEW BEST 12 charges: 3 2 4 3 rmse = 0.71096468765
# 13 CHARGES:
# NEW BEST 13 charges: 3 2 2 6 rmse = 1.0957137075749999
# NEW BEST 13 charges: 3 2 3 5 rmse = 0.7887369731
# NEW BEST 13 charges: 3 2 4 4 rmse = 0.6717643252250001
# NEW BEST 13 charges: 3 2 5 3 rmse = 0.6549542206775
# NEW BEST 13 charges: 3 3 4 3 rmse = 0.62605970575
# 14 CHARGES:
# NEW BEST 14 charges: 3 2 2 7 rmse = 1.080465300925
# NEW BEST 14 charges: 3 2 3 6 rmse = 0.7511315683
# NEW BEST 14 charges: 3 2 4 5 rmse = 0.621618186775
# NEW BEST 14 charges: 3 2 5 4 rmse = 0.6157538582525
# NEW BEST 14 charges: 3 3 4 4 rmse = 0.586859343325
# NEW BEST 14 charges: 3 3 5 3 rmse = 0.5700492387775
# NEW BEST 14 charges: 3 4 4 3 rmse = 0.5273524832250001
# 15 CHARGES:
# NEW BEST 15 charges: 3 2 2 8 rmse = 1.09677200845
# NEW BEST 15 charges: 3 2 3 7 rmse = 0.73588316165
# NEW BEST 15 charges: 3 2 4 6 rmse = 0.5840127819750001
# NEW BEST 15 charges: 3 2 5 5 rmse = 0.5656077198025
# NEW BEST 15 charges: 3 3 4 5 rmse = 0.5367132048750001
# NEW BEST 15 charges: 3 3 5 4 rmse = 0.5308488763525
# NEW BEST 15 charges: 3 4 4 4 rmse = 0.4881521208
# NEW BEST 15 charges: 3 4 5 3 rmse = 0.4713420162525
# NEW BEST 15 charges: 4 4 4 3 rmse = 0.4537595797
# 16 CHARGES:
# NEW BEST 16 charges: 3 2 2 9 rmse = 1.07831306935
# NEW BEST 16 charges: 3 2 3 8 rmse = 0.752189869175
# NEW BEST 16 charges: 3 2 4 7 rmse = 0.568764375325
# NEW BEST 16 charges: 3 2 5 6 rmse = 0.5280023150025
# NEW BEST 16 charges: 3 3 4 6 rmse = 0.499107800075
# NEW BEST 16 charges: 3 3 5 5 rmse = 0.4807027379025
# NEW BEST 16 charges: 3 4 4 5 rmse = 0.43800598235
# NEW BEST 16 charges: 3 4 5 4 rmse = 0.43214165382749997
# NEW BEST 16 charges: 4 4 4 4 rmse = 0.414559217275
# NEW BEST 16 charges: 4 4 5 3 rmse = 0.3977491127275
# NEW BEST 16 charges: 5 4 4 3 rmse = 0.370385553975
# 17 CHARGES:
# NEW BEST 17 charges: 3 2 2 10 rmse = 1.0766958795
# NEW BEST 17 charges: 3 2 3 9 rmse = 0.733730930075
# NEW BEST 17 charges: 3 2 4 8 rmse = 0.58507108285
# NEW BEST 17 charges: 3 2 5 7 rmse = 0.5127539083525
# NEW BEST 17 charges: 3 3 4 7 rmse = 0.483859393425
# NEW BEST 17 charges: 3 3 5 6 rmse = 0.4430973331025
# NEW BEST 17 charges: 3 4 4 6 rmse = 0.40040057754999997
# NEW BEST 17 charges: 3 4 5 5 rmse = 0.3819955153775
# NEW BEST 17 charges: 4 4 4 5 rmse = 0.364413078825
# NEW BEST 17 charges: 4 4 5 4 rmse = 0.3585487503025
# NEW BEST 17 charges: 5 4 4 4 rmse = 0.33118519155
# NEW BEST 17 charges: 5 4 5 3 rmse = 0.31437508700250005
# 18 CHARGES:
# NEW BEST 18 charges: 3 2 2 11 rmse = 1.0720306688749999
# NEW BEST 18 charges: 3 2 3 10 rmse = 0.732113740225
# NEW BEST 18 charges: 3 2 4 9 rmse = 0.56661214375
# NEW BEST 18 charges: 3 2 5 8 rmse = 0.5290606158775
# NEW BEST 18 charges: 3 2 6 7 rmse = 0.50933511018
# NEW BEST 18 charges: 3 3 4 8 rmse = 0.50016610095
# NEW BEST 18 charges: 3 3 5 7 rmse = 0.4278489264525
# NEW BEST 18 charges: 3 4 4 7 rmse = 0.3851521709
# NEW BEST 18 charges: 3 4 5 6 rmse = 0.34439011057749996
# NEW BEST 18 charges: 4 4 4 6 rmse = 0.326807674025
# NEW BEST 18 charges: 4 4 5 5 rmse = 0.3084026118525
# NEW BEST 18 charges: 5 4 4 5 rmse = 0.2810390531
# NEW BEST 18 charges: 5 4 5 4 rmse = 0.27517472457750003
# 19 CHARGES:
# NEW BEST 19 charges: 3 2 2 12 rmse = 1.0637751542675
# NEW BEST 19 charges: 3 2 3 11 rmse = 0.7274485296000001
# NEW BEST 19 charges: 3 2 4 10 rmse = 0.5649949539
# NEW BEST 19 charges: 3 2 5 9 rmse = 0.5106016767775
# NEW BEST 19 charges: 3 2 7 7 rmse = 0.49705051872499995
# NEW BEST 19 charges: 3 3 4 9 rmse = 0.48170716185
# NEW BEST 19 charges: 3 3 5 8 rmse = 0.4441556339775
# NEW BEST 26 charges: 4 4 6 12 rmse = 0.2354398555725
# NEW BEST 26 charges: 4 4 7 11 rmse = 0.231410778725
# NEW BEST 26 charges: 4 5 5 12 rmse = 0.226121955295
# NEW BEST 26 charges: 4 5 7 10 rmse = 0.2233392909
# NEW BEST 26 charges: 4 6 7 9 rmse = 0.219311439505
# NEW BEST 26 charges: 4 8 7 7 rmse = 0.21824524708999998
# NEW BEST 26 charges: 5 4 5 12 rmse = 0.15548462802000002
# NEW BEST 26 charges: 5 4 7 10 rmse = 0.152701963625
# NEW BEST 26 charges: 5 5 5 11 rmse = 0.1510034441775
# NEW BEST 26 charges: 5 5 7 9 rmse = 0.141582455025
# NEW BEST 26 charges: 5 7 7 7 rmse = 0.1379687147725
# NEW BEST 26 charges: 6 6 7 7 rmse = 0.13186489853
# NEW BEST 26 charges: 7 5 5 9 rmse = 0.12486602962749999
# NEW BEST 26 charges: 7 5 7 7 rmse = 0.111314871575
# 27 CHARGES:
# NEW BEST 27 charges: 3 4 8 12 rmse = 0.30907790552
# NEW BEST 27 charges: 3 5 7 12 rmse = 0.2840114691925
# NEW BEST 27 charges: 4 4 7 12 rmse = 0.2231552641175
# NEW BEST 27 charges: 4 5 6 12 rmse = 0.2227031571225
# NEW BEST 27 charges: 4 5 7 11 rmse = 0.218674080275
# NEW BEST 27 charges: 4 6 7 10 rmse = 0.217694249655
# NEW BEST 27 charges: 5 4 6 12 rmse = 0.1520658298475
# NEW BEST 27 charges: 5 4 7 11 rmse = 0.148036753
# NEW BEST 27 charges: 5 5 5 12 rmse = 0.14274792957
# NEW BEST 27 charges: 5 5 7 10 rmse = 0.13996526517500002
# NEW BEST 27 charges: 5 6 7 9 rmse = 0.13593741378000002
# NEW BEST 27 charges: 5 8 7 7 rmse = 0.13487122136500002
# NEW BEST 27 charges: 6 7 7 7 rmse = 0.1317439679475
# NEW BEST 27 charges: 7 4 5 11 rmse = 0.13132032760249998
# NEW BEST 27 charges: 7 4 7 9 rmse = 0.12189933845
# NEW BEST 27 charges: 7 5 6 9 rmse = 0.121447231455
# NEW BEST 27 charges: 7 6 5 9 rmse = 0.1192209883825
# NEW BEST 27 charges: 7 6 7 7 rmse = 0.10566983032999999
# NEW BEST 27 charges: 8 5 7 7 rmse = 0.1037831799
# 28 CHARGES:
# NEW BEST 28 charges: 3 5 8 12 rmse = 0.29634120707
# NEW BEST 28 charges: 3 6 7 12 rmse = 0.27836642794749994
# NEW BEST 28 charges: 4 4 8 12 rmse = 0.235485001995
# NEW BEST 28 charges: 4 5 7 12 rmse = 0.2104185656675
# NEW BEST 28 charges: 5 4 7 12 rmse = 0.1397812383925
# NEW BEST 28 charges: 5 5 6 12 rmse = 0.1393291313975
# NEW BEST 28 charges: 5 5 7 11 rmse = 0.13530005455
# NEW BEST 28 charges: 5 6 7 10 rmse = 0.13432022393
# NEW BEST 28 charges: 6 5 7 10 rmse = 0.13374051835
# NEW BEST 28 charges: 6 6 7 9 rmse = 0.129712666955
# NEW BEST 28 charges: 6 8 7 7 rmse = 0.12864647454
# NEW BEST 28 charges: 7 4 5 12 rmse = 0.123064812995
# NEW BEST 28 charges: 7 4 7 10 rmse = 0.1202821486
# NEW BEST 28 charges: 7 5 5 11 rmse = 0.1185836291525
# NEW BEST 28 charges: 7 5 7 9 rmse = 0.10916264
# NEW BEST 28 charges: 7 7 7 7 rmse = 0.10554889974750001
# NEW BEST 28 charges: 8 6 7 7 rmse = 0.098138138655
# 29 CHARGES:
# NEW BEST 29 charges: 3 6 8 12 rmse = 0.29069616582499996
# NEW BEST 29 charges: 3 7 7 12 rmse = 0.278245497365
# NEW BEST 29 charges: 4 5 8 12 rmse = 0.222748303545
# NEW BEST 29 charges: 4 6 7 12 rmse = 0.20477352442250002
# NEW BEST 29 charges: 5 4 8 12 rmse = 0.15211097627
# NEW BEST 29 charges: 5 5 7 12 rmse = 0.1270445399425
# NEW BEST 29 charges: 7 4 6 12 rmse = 0.1196460148225
# NEW BEST 29 charges: 7 4 7 11 rmse = 0.115616937975
# NEW BEST 29 charges: 7 5 5 12 rmse = 0.110328114545
# NEW BEST 29 charges: 7 5 7 10 rmse = 0.10754545015
# NEW BEST 29 charges: 7 6 7 9 rmse = 0.103517598755
# NEW BEST 29 charges: 7 8 7 7 rmse = 0.10245140634
# NEW BEST 29 charges: 8 5 7 9 rmse = 0.101630948325
# NEW BEST 29 charges: 8 7 7 7 rmse = 0.0980172080725
# NEW BEST 29 charges: 9 6 7 7 rmse = 0.095433661455
# 30 CHARGES:
# NEW BEST 30 charges: 3 7 8 12 rmse = 0.2905752352425
# NEW BEST 30 charges: 3 8 7 12 rmse = 0.27514800395749994
# NEW BEST 30 charges: 4 6 8 12 rmse = 0.21710326230000002
# NEW BEST 30 charges: 4 7 7 12 rmse = 0.20465259384
# NEW BEST 30 charges: 5 5 8 12 rmse = 0.13937427782
# NEW BEST 30 charges: 5 6 7 12 rmse = 0.12139949869750001
# NEW BEST 30 charges: 6 5 7 12 rmse = 0.1208197931175
# NEW BEST 30 charges: 7 4 7 12 rmse = 0.1073614233675
# NEW BEST 30 charges: 7 5 6 12 rmse = 0.1069093163725
# NEW BEST 30 charges: 7 5 7 11 rmse = 0.102880239525
# NEW BEST 30 charges: 7 6 7 10 rmse = 0.101900408905
# NEW BEST 30 charges: 8 5 7 10 rmse = 0.100013758475
# NEW BEST 30 charges: 8 6 7 9 rmse = 0.09598590708
# NEW BEST 30 charges: 8 8 7 7 rmse = 0.09491971466499999
# NEW BEST 30 charges: 10 6 7 7 rmse = 0.09196262898
# 31 CHARGES:
# NEW BEST 31 charges: 3 8 8 12 rmse = 0.28747774183499997
# NEW BEST 31 charges: 4 7 8 12 rmse = 0.2169823317175
# NEW BEST 31 charges: 4 8 7 12 rmse = 0.2015551004325
# NEW BEST 31 charges: 5 6 8 12 rmse = 0.133729236575
# NEW BEST 31 charges: 5 7 7 12 rmse = 0.12127856811500001
# NEW BEST 31 charges: 6 6 7 12 rmse = 0.11517475187250001
# NEW BEST 31 charges: 7 5 7 12 rmse = 0.0946247249175
# NEW BEST 31 charges: 8 6 7 10 rmse = 0.09436871723000001
# NEW BEST 31 charges: 9 6 7 9 rmse = 0.09328142988
# NEW BEST 31 charges: 9 8 7 7 rmse = 0.09221523746499999
# NEW BEST 31 charges: 10 7 7 7 rmse = 0.0918416983975
# NEW BEST 31 charges: 11 6 7 7 rmse = 0.08754738717999999
# 32 CHARGES:
# NEW BEST 32 charges: 4 8 8 12 rmse = 0.21388483831
# NEW BEST 32 charges: 5 7 8 12 rmse = 0.1336083059925
# NEW BEST 32 charges: 5 8 7 12 rmse = 0.11818107470750001
# NEW BEST 32 charges: 6 7 7 12 rmse = 0.11505382129000001
# NEW BEST 32 charges: 7 5 8 12 rmse = 0.106954462795
# NEW BEST 32 charges: 7 6 7 12 rmse = 0.0889796836725
# NEW BEST 32 charges: 8 5 7 12 rmse = 0.0870930332425
# 33 CHARGES:
# NEW BEST 33 charges: 5 8 8 12 rmse = 0.130510812585
# NEW BEST 33 charges: 6 7 8 12 rmse = 0.1273835591675
# NEW BEST 33 charges: 6 8 7 12 rmse = 0.11195632788250001
# NEW BEST 33 charges: 7 6 8 12 rmse = 0.10130942155
# NEW BEST 33 charges: 7 7 7 12 rmse = 0.08885875309
# NEW BEST 33 charges: 8 6 7 12 rmse = 0.0814479919975
# 34 CHARGES:
# NEW BEST 34 charges: 6 8 8 12 rmse = 0.12428606576000001
# NEW BEST 34 charges: 7 7 8 12 rmse = 0.1011884909675
# NEW BEST 34 charges: 7 8 7 12 rmse = 0.08576125968250001
# NEW BEST 34 charges: 8 7 7 12 rmse = 0.081327061415
# NEW BEST 34 charges: 9 6 7 12 rmse = 0.0787435147975
# 35 CHARGES:
# NEW BEST 35 charges: 7 8 8 12 rmse = 0.09809099756
# NEW BEST 35 charges: 8 7 8 12 rmse = 0.0936567992925
# NEW BEST 35 charges: 8 8 7 12 rmse = 0.0782295680075
# NEW BEST 35 charges: 10 6 7 12 rmse = 0.0752724823225
# 36 CHARGES:
# NEW BEST 36 charges: 8 8 8 12 rmse = 0.090559305885
# NEW BEST 36 charges: 9 8 7 12 rmse = 0.0755250908075
# NEW BEST 36 charges: 10 7 7 12 rmse = 0.07515155174
# NEW BEST 36 charges: 11 6 7 12 rmse = 0.0708572405225
# 37 CHARGES:
# NEW BEST 37 charges: 9 8 8 12 rmse = 0.087854828685
# NEW BEST 37 charges: 10 7 8 12 rmse = 0.0874812896175
# NEW BEST 37 charges: 10 8 7 12 rmse = 0.0720540583325
# NEW BEST 37 charges: 11 7 7 12 rmse = 0.07073630994
# 38 CHARGES:
# NEW BEST 38 charges: 10 8 8 12 rmse = 0.08438379621
# NEW BEST 38 charges: 11 7 8 12 rmse = 0.0830660478175
# NEW BEST 38 charges: 11 8 7 12 rmse = 0.0676388165325
# 39 CHARGES:
# NEW BEST 39 charges: 11 8 8 12 rmse = 0.07996855441
# NEW BEST 39 charges: 12 8 7 12 rmse = 0.0681710979825
# 40 CHARGES:
# NEW BEST 40 charges: 12 8 8 12 rmse = 0.08050083586000001

# %%
pydcm.refine_models()
# Out:
# Summary of results:
# 10 charges, RMSE: 1.045341076 kcal/mol
# 11 charges, RMSE: 1.069072232 kcal/mol
# 12 charges, RMSE: 1.014872451 kcal/mol
# 13 charges, RMSE: 0.9753178193 kcal/mol
# 14 charges, RMSE: 0.8574946602 kcal/mol
# 15 charges, RMSE: 0.7877106442 kcal/mol
# 16 charges, RMSE: 0.6631946022 kcal/mol
# 17 charges, RMSE: 0.6690097627 kcal/mol
# 18 charges, RMSE: 0.6313166616 kcal/mol
# 19 charges, RMSE: 0.5688686855 kcal/mol
# 20 charges, RMSE: 0.5360864516 kcal/mol
# 21 charges, RMSE: 0.5309868844 kcal/mol
# 22 charges, RMSE: 0.5193661433 kcal/mol
# 23 charges, RMSE: 0.5136091996 kcal/mol
# 24 charges, RMSE: 0.5100842174 kcal/mol
# 25 charges, RMSE: 0.5072128325 kcal/mol
# 26 charges, RMSE: 0.5145492169 kcal/mol
# 27 charges, RMSE: 0.5109058541 kcal/mol
# 28 charges, RMSE: 0.5088203305 kcal/mol
# 29 charges, RMSE: 0.5060637883 kcal/mol
# 30 charges, RMSE: 0.5089921728 kcal/mol
# 31 charges, RMSE: 0.5073012353 kcal/mol
# 32 charges, RMSE: 0.507437606 kcal/mol
# 33 charges, RMSE: 0.5032474157 kcal/mol
# 34 charges, RMSE: 0.5037072859 kcal/mol
# 35 charges, RMSE: 0.5039431379 kcal/mol
# 36 charges, RMSE: 0.5005608993 kcal/mol
# 37 charges, RMSE: 0.5006388591 kcal/mol
# 38 charges, RMSE: 0.5006786048 kcal/mol
# 39 charges, RMSE: 0.4988228125 kcal/mol
# 40 charges, RMSE: 0.4971134229 kcal/mol

# %%
pydcm.analyse_model(20)
# Out:
# Ditriantapole RMSE: 3.799888416E-01
# 0.04845684579
# Monopole RMSE: 8.029232540E-01
# 0.206634443
# satisfied
# Quadrupole RMSE: 3.806049986E-01
# 0.04876728984
# 20 charge model RMSE: 4.104549475E-01
# 0.06484723241
# [0.3799888416, 0.8100493809, 0.122851282, 0.04845684579, 0.802923254, 1.586146251, 0.5155074333, 0.206634443, 0.3806049986, 0.8112678472, 0.1233018696, 0.04876728984, 0.4104549475, 0.8621458337, 0.169165466, 0.06484723241]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3dbc249b8741> in <module>
# ----> 1 pydcm.analyse_model(20)
#
# ~/pydcm/_pydcm.py in analyse_model(self, nchg, isoSurf)
#    1750
#    1751         # SHOW SLICES FROM R
# -> 1752         writeNGLHTML2('analyze.html', 'ref/' + os.path.basename(densCube), errorFiles[2],
#    1753                       'ref/' + os.path.basename(densCube),
#    1754                       cubeFiles[4], rmse, maxErr, npts, '6-analysis/' + moldir + '/comparison.png')
#
# NameError: name 'densCube' is not defined

# %%
pydcm.refinedir
