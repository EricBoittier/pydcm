# %%
import sys
ars_path = "/home/boittier/pydcm/"
sys.path.insert(1, ars_path)
from _pydcm import *

# The Gaussian-format cube file containing electron density:
refDensCube="/home/boittier/B.pdb/OPT_B3LYP_6-31+G/B.d.cube"
# The Gaussian-format cube file containing electrostatic potential energy:
refPotCube="/home/boittier/B.pdb/OPT_B3LYP_6-31+G/B.p.cube"
# The root folder for your fitting project
projDir="/home/boittier/pydcm/models/fbutadiene-0"
# The bin directory containing the MDCM scripts and programs
refBinDir="/home/boittier/pydcm/bin"
# The total charge of the molecule to be fitted (a.u.)
qtot=0.0
# The port to use for the local web browser (to view molecules in NGL). Make sure nobody else is using it already!
webPort='8880'
# The name of a Slurm partition allowing jobs to run for up to 2 hours with 4 cores
shortQ='short'
longQ='infinite'
# The desired isodensity surface to use for viewing potential energy surfaces (a.u)
isoSurf=0.001

# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Maximum number of charges to fit per atom (minimum is fixed at 1)
maxAChg=4

minMChg=18
maxMChg=54

natm=10
nfrag = 4

# Define fragments using atom numbering from NGL window at top of notebook
frags=[[9, 10, 4],[3,8],[7,2],[5,1,6]]
# Minimum number of charges to fit for each fragment (can average fewer than 1 per atom)
minFChg=[3,2,2,3]
# Maximum number of charges to fit for each fragment (upper limit per atom fixed by maxAChg)
maxFChg=[12,8,8,12]



workdir = projDir + '/'
refdir = workdir + 'ref/'
htmldir = workdir + 'html/'
bindir = refBinDir + '/'
pdbfile = refdir + 'mol.pdb'
densCube = refdir + os.path.basename(refDensCube)
potCube = refdir + os.path.basename(refPotCube)

# %%
pydcm = Pydcm(projDir, refBinDir, refDensCube, refPotCube, webPort, frags, minFChg, maxFChg, maxAChg, minMChg, maxMChg, shortQ, longQ)

# %%
pydcm.make_ref_directory()
pydcm.start_server()
# Out:
# Changed to working directory /home/boittier/pydcm/models/fbutadiene-0/
# 10 atoms in molecule
# writing PDB file /home/boittier/pydcm/models/fbutadiene-0/ref/mol.pdb
#
# Running jobs:python /home/boittier/pydcm/bin/simple-cors-http-server.py 8880
# 0 : run_http()
#
# Web server running in directory /home/boittier/pydcm/models/fbutadiene-0, URLs are relative to this path
#
# If you change the project directory, you need to restart Jupyter-Lab to restart this server and create a new root for URLs

# %%
pydcm.show_ref_models()
# Out:
# ESP range: -0.0333205 to 0.0333205 a.u.
# 8880 /home/boittier/pydcm/models/fbutadiene-0/html/ /home/boittier/pydcm/models/fbutadiene-0/ref/mol.pdb
# http://localhost:8880/html/refESP.html
#         <iframe
#             width="1120"
#             height="750"
#             src="http://localhost:8880/html/refESP.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.display_mtpfit_comparison()
# Out:
# /home/boittier/pydcm/bin/mtpfit.py
#         <iframe
#             width="1120"
#             height="1550"
#             src="http://localhost:8880/html/mtpFit.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.do_atom_fit(maxAChg, ntry, nfrag)
# Out:
# ## 1Charges Per Atom:
# Atom 1 final RMSE: 1.355010768 kcal/mol
# Atom 2 final RMSE: 1.177383309 kcal/mol
# Atom 3 final RMSE: 3.364771098 kcal/mol
# Atom 4 final RMSE: 2.648605279 kcal/mol
# Atom 5 final RMSE: 3.368588998 kcal/mol
# Atom 6 final RMSE: 0.7207259581 kcal/mol
# Atom 7 final RMSE: 2.045873006 kcal/mol
# Atom 8 final RMSE: 1.698403403 kcal/mol
# Atom 9 final RMSE: 1.062961645 kcal/mol
# Atom 10 final RMSE: 2.358409832 kcal/mol
#
# ## 2Charges Per Atom:
# Atom 1 final RMSE: 0.930872398 kcal/mol
# Atom 2 final RMSE: 1.025416339 kcal/mol
# Atom 3 final RMSE: 0.5414976401 kcal/mol
# Atom 4 final RMSE: 0.9886715665 kcal/mol
# Atom 5 final RMSE: 0.2269288667 kcal/mol
# Atom 6 final RMSE: 0.5446363464 kcal/mol
# Atom 7 final RMSE: 0.8298174583 kcal/mol
# Atom 8 final RMSE: 0.5299056857 kcal/mol
# Atom 9 final RMSE: 0.9427496939 kcal/mol
# Atom 10 final RMSE: 0.7922691422 kcal/mol
#
# ## 3Charges Per Atom:
# Atom 1 final RMSE: 0.4716542291 kcal/mol
# Atom 2 final RMSE: 0.3501257358 kcal/mol
# Atom 3 final RMSE: 0.1479215311 kcal/mol
# Atom 4 final RMSE: 0.2576493213 kcal/mol
# Atom 5 final RMSE: 0.1072104017 kcal/mol
# Atom 6 final RMSE: 0.267535146 kcal/mol
# Atom 7 final RMSE: 0.5225854779 kcal/mol
# Atom 8 final RMSE: 0.2302200693 kcal/mol
# Atom 9 final RMSE: 0.3625339295 kcal/mol
# Atom 10 final RMSE: 0.1496599675 kcal/mol
#
# ## 4Charges Per Atom:
# Atom 1 final RMSE: 0.1163559321 kcal/mol
# Atom 2 final RMSE: 0.1206838005 kcal/mol
# Atom 3 final RMSE: 0.1002871255 kcal/mol
# Atom 4 final RMSE: 0.1542650095 kcal/mol
# Atom 5 final RMSE: 0.06351142202 kcal/mol
# Atom 6 final RMSE: 0.07869371387 kcal/mol
# Atom 7 final RMSE: 0.08411887442 kcal/mol
# Atom 8 final RMSE: 0.05843241394 kcal/mol
# Atom 9 final RMSE: 0.1031254632 kcal/mol
# Atom 10 final RMSE: 0.06494620602 kcal/mol

# %%
# START OF USER VARIABLES

# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Number of separate fits to perform (restarting a fit can lead to a better outcome). Cost scales linearly
nfit=2


pydcm.fit_fragments(ntry, nfit)
# Out:
# Summary of results:
# Frag 1, Fit 1, 3 charges, RMSE: 0.3941508829 kcal/mol
# Frag 1, Fit 1, 4 charges, RMSE: 0.3006551332 kcal/mol
# Frag 1, Fit 1, 5 charges, RMSE: 0.1955202402 kcal/mol
# Frag 1, Fit 1, 6 charges, RMSE: 0.1616838791 kcal/mol
# Frag 1, Fit 1, 7 charges, RMSE: 0.1615261492 kcal/mol
# Frag 1, Fit 1, 8 charges, RMSE: 0.1419924783 kcal/mol
# Frag 1, Fit 1, 9 charges, RMSE: 0.1462646094 kcal/mol
# Frag 1, Fit 1, 10 charges, RMSE: 0.08672859741 kcal/mol
# Frag 1, Fit 1, 11 charges, RMSE: 0.07425026578 kcal/mol
# Frag 1, Fit 1, 12 charges, RMSE: 0.08050178687 kcal/mol
# Frag 1, Fit 2, 3 charges, RMSE: 0.394150883 kcal/mol
# Frag 1, Fit 2, 4 charges, RMSE: 0.332229844 kcal/mol
# Frag 1, Fit 2, 5 charges, RMSE: 0.285259529 kcal/mol
# Frag 1, Fit 2, 6 charges, RMSE: 0.1852875007 kcal/mol
# Frag 1, Fit 2, 7 charges, RMSE: 0.1893447721 kcal/mol
# Frag 1, Fit 2, 8 charges, RMSE: 0.1605255228 kcal/mol
# Frag 1, Fit 2, 9 charges, RMSE: 0.12897926 kcal/mol
# Frag 1, Fit 2, 10 charges, RMSE: 0.0966866991 kcal/mol
# Frag 1, Fit 2, 11 charges, RMSE: 0.07191133095 kcal/mol
# Frag 1, Fit 2, 12 charges, RMSE: 0.06173366199 kcal/mol
# Frag 2, Fit 1, 2 charges, RMSE: 0.7332989233 kcal/mol
# Frag 2, Fit 1, 3 charges, RMSE: 0.3133145461 kcal/mol
# Frag 2, Fit 1, 4 charges, RMSE: 0.2200472899 kcal/mol
# Frag 2, Fit 1, 5 charges, RMSE: 0.1030120117 kcal/mol
# Frag 2, Fit 1, 6 charges, RMSE: 0.07015017102 kcal/mol
# Frag 2, Fit 1, 7 charges, RMSE: 0.05404187165 kcal/mol
# Frag 2, Fit 1, 8 charges, RMSE: 0.04684085272 kcal/mol
# Frag 2, Fit 2, 2 charges, RMSE: 0.7332989233 kcal/mol
# Frag 2, Fit 2, 3 charges, RMSE: 0.3133145471 kcal/mol
# Frag 2, Fit 2, 4 charges, RMSE: 0.1657241777 kcal/mol
# Frag 2, Fit 2, 5 charges, RMSE: 0.1078538908 kcal/mol
# Frag 2, Fit 2, 6 charges, RMSE: 0.07843010881 kcal/mol
# Frag 2, Fit 2, 7 charges, RMSE: 0.05919784812 kcal/mol
# Frag 2, Fit 2, 8 charges, RMSE: 0.05048295761 kcal/mol
# Frag 3, Fit 1, 2 charges, RMSE: 0.7186782803 kcal/mol
# Frag 3, Fit 1, 3 charges, RMSE: 0.5013715383 kcal/mol
# Frag 3, Fit 1, 4 charges, RMSE: 0.4658935223 kcal/mol
# Frag 3, Fit 1, 5 charges, RMSE: 0.2842392509 kcal/mol
# Frag 3, Fit 1, 6 charges, RMSE: 0.2625222107 kcal/mol
# Frag 3, Fit 1, 7 charges, RMSE: 0.1766700935 kcal/mol
# Frag 3, Fit 1, 8 charges, RMSE: 0.08231831769 kcal/mol
# Frag 3, Fit 2, 2 charges, RMSE: 0.71867828 kcal/mol
# Frag 3, Fit 2, 3 charges, RMSE: 0.5013715385 kcal/mol
# Frag 3, Fit 2, 4 charges, RMSE: 0.386141159 kcal/mol
# Frag 3, Fit 2, 5 charges, RMSE: 0.2593163373 kcal/mol
# Frag 3, Fit 2, 6 charges, RMSE: 0.3052792669 kcal/mol
# Frag 3, Fit 2, 7 charges, RMSE: 0.1847048815 kcal/mol
# Frag 3, Fit 2, 8 charges, RMSE: 0.06774090824 kcal/mol
# Frag 4, Fit 1, 3 charges, RMSE: 0.2904947167 kcal/mol
# Frag 4, Fit 1, 4 charges, RMSE: 0.1750202745 kcal/mol
# Frag 4, Fit 1, 5 charges, RMSE: 0.2634016484 kcal/mol
# Frag 4, Fit 1, 6 charges, RMSE: 0.1185095506 kcal/mol
# Frag 4, Fit 1, 7 charges, RMSE: 0.127970432 kcal/mol
# Frag 4, Fit 1, 8 charges, RMSE: 0.09144700179 kcal/mol
# Frag 4, Fit 1, 9 charges, RMSE: 0.05763083991 kcal/mol
# Frag 4, Fit 1, 10 charges, RMSE: 0.05249973148 kcal/mol
# Frag 4, Fit 1, 11 charges, RMSE: 0.03547271173 kcal/mol
# Frag 4, Fit 1, 12 charges, RMSE: 0.0452326237 kcal/mol
# Frag 4, Fit 2, 3 charges, RMSE: 0.2904947168 kcal/mol
# Frag 4, Fit 2, 4 charges, RMSE: 0.1750203521 kcal/mol
# Frag 4, Fit 2, 5 charges, RMSE: 0.1405719709 kcal/mol
# Frag 4, Fit 2, 6 charges, RMSE: 0.2670114353 kcal/mol
# Frag 4, Fit 2, 7 charges, RMSE: 0.09568921571 kcal/mol
# Frag 4, Fit 2, 8 charges, RMSE: 0.1945223058 kcal/mol
# Frag 4, Fit 2, 9 charges, RMSE: 0.06432166851 kcal/mol
# Frag 4, Fit 2, 10 charges, RMSE: 0.05315964794 kcal/mol
# Frag 4, Fit 2, 11 charges, RMSE: 0.04717558992 kcal/mol
# Frag 4, Fit 2, 12 charges, RMSE: 0.04667878222 kcal/mol

# %%
pydcm.combine_fragements(ntry, nfit)
# Out:
# 18 CHARGES:
# NEW BEST 18 charges: 3 2 2 11 rmse = 0.4704001994825
# NEW BEST 18 charges: 3 2 3 10 rmse = 0.420330268995
# NEW BEST 18 charges: 3 2 4 9 rmse = 0.39280545127750005
# NEW BEST 18 charges: 3 2 5 8 rmse = 0.3695532863225
# NEW BEST 18 charges: 3 2 7 6 rmse = 0.355657362575
# NEW BEST 18 charges: 3 2 8 5 rmse = 0.333940671335
# NEW BEST 18 charges: 3 3 3 9 rmse = 0.3166169518025
# NEW BEST 18 charges: 3 3 4 8 rmse = 0.2962633974475
# NEW BEST 18 charges: 3 3 5 7 rmse = 0.2656177455025
# NEW BEST 18 charges: 3 3 7 5 rmse = 0.25617687335
# NEW BEST 18 charges: 3 3 8 4 rmse = 0.237556652935
# NEW BEST 18 charges: 3 4 5 6 rmse = 0.23442523712500002
# NEW BEST 18 charges: 3 4 7 4 rmse = 0.22789135715
# NEW BEST 18 charges: 3 5 5 5 rmse = 0.2242628007
# NEW BEST 18 charges: 4 4 5 5 rmse = 0.21656690477499996
# NEW BEST 18 charges: 4 5 5 4 rmse = 0.209500939175
# NEW BEST 18 charges: 5 4 5 4 rmse = 0.198895257425
# 19 CHARGES:
# NEW BEST 19 charges: 3 2 2 12 rmse = 0.472840177475
# NEW BEST 19 charges: 3 2 3 11 rmse = 0.4160735140575
# NEW BEST 19 charges: 3 2 4 10 rmse = 0.39152267417000003
# NEW BEST 24 charges: 5 4 8 7 rmse = 0.13116863546250002
# NEW BEST 24 charges: 5 5 8 6 rmse = 0.121195677685
# NEW BEST 24 charges: 5 6 8 5 rmse = 0.11849582259000001
# NEW BEST 24 charges: 6 5 8 5 rmse = 0.118252192485
# 25 CHARGES:
# NEW BEST 25 charges: 3 2 8 12 rmse = 0.310105834535
# NEW BEST 25 charges: 3 3 7 12 rmse = 0.23234203655
# NEW BEST 25 charges: 3 3 8 11 rmse = 0.2026697622425
# NEW BEST 25 charges: 3 4 7 11 rmse = 0.1930044664575
# NEW BEST 25 charges: 3 4 8 10 rmse = 0.17002892508
# NEW BEST 25 charges: 3 5 8 9 rmse = 0.15563366068749998
# NEW BEST 25 charges: 3 7 8 7 rmse = 0.152905719625
# NEW BEST 25 charges: 4 4 8 9 rmse = 0.14793776476249998
# NEW BEST 25 charges: 4 5 8 8 rmse = 0.1407137637325
# NEW BEST 25 charges: 4 6 8 7 rmse = 0.13355885704249998
# NEW BEST 25 charges: 5 4 8 8 rmse = 0.1301080819825
# NEW BEST 25 charges: 5 5 8 7 rmse = 0.1154905939625
# NEW BEST 25 charges: 5 6 8 6 rmse = 0.11298021751500001
# NEW BEST 25 charges: 6 5 8 6 rmse = 0.11273658741
# NEW BEST 25 charges: 6 6 8 5 rmse = 0.11003673231500001
# 26 CHARGES:
# NEW BEST 26 charges: 3 3 8 12 rmse = 0.205109740235
# NEW BEST 26 charges: 3 4 7 12 rmse = 0.19544444445
# NEW BEST 26 charges: 3 4 8 11 rmse = 0.1657721701425
# NEW BEST 26 charges: 3 5 8 10 rmse = 0.15435088358
# NEW BEST 26 charges: 3 6 8 9 rmse = 0.1474182005175
# NEW BEST 26 charges: 4 4 8 10 rmse = 0.14665498765499999
# NEW BEST 26 charges: 4 5 8 9 rmse = 0.1322597232625
# NEW BEST 26 charges: 4 7 8 7 rmse = 0.1295317822
# NEW BEST 26 charges: 5 4 8 9 rmse = 0.1216540415125
# NEW BEST 26 charges: 5 5 8 8 rmse = 0.1144300404825
# NEW BEST 26 charges: 5 6 8 7 rmse = 0.1072751337925
# NEW BEST 26 charges: 6 5 8 7 rmse = 0.1070315036875
# NEW BEST 26 charges: 6 6 8 6 rmse = 0.10452112724000001
# 27 CHARGES:
# NEW BEST 27 charges: 3 4 8 12 rmse = 0.16821214813500002
# NEW BEST 27 charges: 3 5 8 11 rmse = 0.1500941286425
# NEW BEST 27 charges: 3 6 8 10 rmse = 0.14613542341
# NEW BEST 27 charges: 3 7 8 9 rmse = 0.14339112567499998
# NEW BEST 27 charges: 4 4 8 11 rmse = 0.1423982327175
# NEW BEST 27 charges: 4 5 8 10 rmse = 0.130976946155
# NEW BEST 27 charges: 4 6 8 9 rmse = 0.1240442630925
# NEW BEST 27 charges: 5 4 8 10 rmse = 0.120371264405
# NEW BEST 27 charges: 5 5 8 9 rmse = 0.1059760000125
# NEW BEST 27 charges: 5 7 8 7 rmse = 0.10324805895
# NEW BEST 27 charges: 6 6 8 7 rmse = 0.09881604351750001
# 28 CHARGES:
# NEW BEST 28 charges: 3 5 8 12 rmse = 0.152534106635
# NEW BEST 28 charges: 3 6 8 11 rmse = 0.1418786684725
# NEW BEST 28 charges: 3 8 8 9 rmse = 0.14159087094249997
# NEW BEST 28 charges: 4 5 8 11 rmse = 0.1267201912175
# NEW BEST 28 charges: 4 6 8 10 rmse = 0.12276148598499999
# NEW BEST 28 charges: 4 7 8 9 rmse = 0.12001718825
# NEW BEST 28 charges: 5 4 8 11 rmse = 0.1161145094675
# NEW BEST 28 charges: 5 5 8 10 rmse = 0.104693222905
# NEW BEST 28 charges: 5 6 8 9 rmse = 0.09776053984250001
# NEW BEST 28 charges: 6 5 8 9 rmse = 0.0975169097375
# NEW BEST 28 charges: 6 7 8 7 rmse = 0.094788968675
# 29 CHARGES:
# NEW BEST 29 charges: 3 6 8 12 rmse = 0.144318646465
# NEW BEST 29 charges: 3 7 8 11 rmse = 0.13785159363
# NEW BEST 29 charges: 4 5 8 12 rmse = 0.12916016921
# NEW BEST 29 charges: 4 6 8 11 rmse = 0.11850473104749999
# NEW BEST 29 charges: 4 8 8 9 rmse = 0.1182169335175
# NEW BEST 29 charges: 5 5 8 11 rmse = 0.1004364679675
# NEW BEST 29 charges: 5 6 8 10 rmse = 0.096477762735
# NEW BEST 29 charges: 5 7 8 9 rmse = 0.093733465
# NEW BEST 29 charges: 6 6 8 9 rmse = 0.08930144956750001
# 30 CHARGES:
# NEW BEST 30 charges: 3 7 8 12 rmse = 0.1402915716225
# NEW BEST 30 charges: 3 8 8 11 rmse = 0.13605133889749998
# NEW BEST 30 charges: 4 6 8 12 rmse = 0.12094470903999999
# NEW BEST 30 charges: 4 7 8 11 rmse = 0.114477656205
# NEW BEST 30 charges: 5 5 8 12 rmse = 0.10287644596000001
# NEW BEST 30 charges: 5 6 8 11 rmse = 0.0922210077975
# NEW BEST 30 charges: 5 8 8 9 rmse = 0.0919332102675
# NEW BEST 30 charges: 6 6 8 10 rmse = 0.08801867246
# NEW BEST 30 charges: 6 7 8 9 rmse = 0.085274374725
# 31 CHARGES:
# NEW BEST 31 charges: 3 8 8 12 rmse = 0.13849131689
# NEW BEST 31 charges: 4 7 8 12 rmse = 0.11691763419750001
# NEW BEST 31 charges: 4 8 8 11 rmse = 0.1126774014725
# NEW BEST 31 charges: 5 6 8 12 rmse = 0.09466098579000001
# NEW BEST 31 charges: 5 7 8 11 rmse = 0.088193932955
# NEW BEST 31 charges: 6 6 8 11 rmse = 0.0837619175225
# NEW BEST 31 charges: 6 8 8 9 rmse = 0.0834741199925
# NEW BEST 31 charges: 10 6 8 7 rmse = 0.080077223095
# 32 CHARGES:
# NEW BEST 32 charges: 4 8 8 12 rmse = 0.115117379465
# NEW BEST 32 charges: 5 7 8 12 rmse = 0.09063391094750001
# NEW BEST 32 charges: 5 8 8 11 rmse = 0.08639367822249999
# NEW BEST 32 charges: 6 6 8 12 rmse = 0.08620189551500002
# NEW BEST 32 charges: 6 7 8 11 rmse = 0.07973484268
# NEW BEST 32 charges: 10 5 8 9 rmse = 0.07877808931500001
# NEW BEST 32 charges: 10 7 8 7 rmse = 0.07605014825249999
# 33 CHARGES:
# NEW BEST 33 charges: 5 8 8 12 rmse = 0.088833656215
# NEW BEST 33 charges: 6 7 8 12 rmse = 0.08217482067250001
# NEW BEST 33 charges: 6 8 8 11 rmse = 0.0779345879475
# NEW BEST 33 charges: 9 7 8 9 rmse = 0.07709821995
# NEW BEST 33 charges: 10 6 8 9 rmse = 0.070562629145
# 34 CHARGES:
# NEW BEST 34 charges: 6 8 8 12 rmse = 0.08037456594
# NEW BEST 34 charges: 7 8 8 11 rmse = 0.07789515547249999
# NEW BEST 34 charges: 8 7 8 11 rmse = 0.07481199247999999
# NEW BEST 34 charges: 10 5 8 11 rmse = 0.07323855727
# NEW BEST 34 charges: 10 6 8 10 rmse = 0.06927985203749999
# NEW BEST 34 charges: 10 7 8 9 rmse = 0.0665355543025
# 35 CHARGES:
# NEW BEST 35 charges: 7 8 8 12 rmse = 0.08033513346499999
# NEW BEST 35 charges: 8 7 8 12 rmse = 0.07725197047249999
# NEW BEST 35 charges: 8 8 8 11 rmse = 0.0730117377475
# NEW BEST 35 charges: 9 7 8 11 rmse = 0.071558687905
# NEW BEST 35 charges: 10 6 8 11 rmse = 0.0650230971
# NEW BEST 35 charges: 10 8 8 9 rmse = 0.06473529957
# NEW BEST 35 charges: 11 7 8 9 rmse = 0.0628312376875
# 36 CHARGES:
# NEW BEST 36 charges: 8 8 8 12 rmse = 0.07545171574000001
# NEW BEST 36 charges: 9 7 8 12 rmse = 0.07399866589750001
# NEW BEST 36 charges: 9 8 8 11 rmse = 0.0697584331725
# NEW BEST 36 charges: 10 6 8 12 rmse = 0.06746307509249999
# NEW BEST 36 charges: 10 7 8 11 rmse = 0.06099602225749999
# NEW BEST 36 charges: 12 7 8 9 rmse = 0.0602868204475
# 37 CHARGES:
# NEW BEST 37 charges: 9 8 8 12 rmse = 0.072198411165
# NEW BEST 37 charges: 10 7 8 12 rmse = 0.06343600024999999
# NEW BEST 37 charges: 10 8 8 11 rmse = 0.059195767525
# NEW BEST 37 charges: 11 7 8 11 rmse = 0.057291705642499996
# 38 CHARGES:
# NEW BEST 38 charges: 10 8 8 12 rmse = 0.0616357455175
# NEW BEST 38 charges: 11 7 8 12 rmse = 0.059731683635
# NEW BEST 38 charges: 11 8 8 11 rmse = 0.055491450910000004
# NEW BEST 38 charges: 12 7 8 11 rmse = 0.0547472884025
# 39 CHARGES:
# NEW BEST 39 charges: 11 8 8 12 rmse = 0.057931428902500005
# NEW BEST 39 charges: 12 7 8 12 rmse = 0.057187266395
# NEW BEST 39 charges: 12 8 8 11 rmse = 0.05294703367
# 40 CHARGES:
# NEW BEST 40 charges: 12 8 8 12 rmse = 0.0553870116625
# 41 CHARGES:
# Could not satisfy 41 charges with available fragments
# 42 CHARGES:
# Could not satisfy 42 charges with available fragments
# 43 CHARGES:
# Could not satisfy 43 charges with available fragments
# 44 CHARGES:
# Could not satisfy 44 charges with available fragments
# 45 CHARGES:
# Could not satisfy 45 charges with available fragments
# 46 CHARGES:
# Could not satisfy 46 charges with available fragments
# 47 CHARGES:
# Could not satisfy 47 charges with available fragments
# 48 CHARGES:
# Could not satisfy 48 charges with available fragments
# 49 CHARGES:
# Could not satisfy 49 charges with available fragments
# 50 CHARGES:
# Could not satisfy 50 charges with available fragments
# 51 CHARGES:
# Could not satisfy 51 charges with available fragments
# 52 CHARGES:
# Could not satisfy 52 charges with available fragments
# 53 CHARGES:
# Could not satisfy 53 charges with available fragments
# 54 CHARGES:
# Could not satisfy 54 charges with available fragments

# %%
pydcm.refine_models()
# Out:
# Job 3481636 has crashed, resubmitting
# submitted jobID 3483033
# Job 3481637 has crashed, resubmitting
# submitted jobID 3483034
# Job 3481638 has crashed, resubmitting
# submitted jobID 3483035
# Job 3481639 has crashed, resubmitting
# submitted jobID 3483036
# No model with 41charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 42charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 43charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 44charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 45charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 46charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 47charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 48charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 49charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 50charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 51charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 52charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 53charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
# No model with 54charges exists in /home/boittier/pydcm/models/fbutadiene-0/4-combine/
#
# Summary of results:
# 18 charges, RMSE: 0.5177958693 kcal/mol
# 19 charges, RMSE: 0.5141406777 kcal/mol
# 20 charges, RMSE: 0.5200775982 kcal/mol
# 21 charges, RMSE: 0.4925570913 kcal/mol
# 22 charges, RMSE: 0.4954574653 kcal/mol
# 23 charges, RMSE: 0.4929717866 kcal/mol
# 24 charges, RMSE: 0.4972105058 kcal/mol
# 25 charges, RMSE: 0.4948289356 kcal/mol
# 26 charges, RMSE: 0.4922762742 kcal/mol
# 27 charges, RMSE: 0.491384644 kcal/mol
# 28 charges, RMSE: 0.4918398862 kcal/mol
# 29 charges, RMSE: 0.489032558 kcal/mol
# 30 charges, RMSE: 0.4906846089 kcal/mol
# 31 charges, RMSE: 0.4849173812 kcal/mol
# 32 charges, RMSE: 0.48523976 kcal/mol
# 33 charges, RMSE: 0.4838029689 kcal/mol
# 34 charges, RMSE: 0.4836591355 kcal/mol
# 35 charges, RMSE: 0.4829211201 kcal/mol
# 36 charges, RMSE: 0.4813799903 kcal/mol
