# %%
import sys
ars_path = "/home/boittier/pydcm/"
sys.path.insert(1, ars_path)
from _pydcm import *

# %%
# The Gaussian-format cube file containing electron density:
refDensCube="/home/boittier/B.pdb/SCAN_1_2_3_4_S_36_10.0/9_SCAN/B.d.cube"
# The Gaussian-format cube file containing electrostatic potential energy:
refPotCube="/home/boittier/B.pdb/SCAN_1_2_3_4_S_36_10.0/9_SCAN/B.p.cube"
# The root folder for your fitting project
projDir="/home/boittier/pydcm/models/fbutadiene-9"
# The bin directory containing the MDCM scripts and programs
refBinDir="/home/boittier/pydcm/bin"
# The total charge of the molecule to be fitted (a.u.)
qtot=0.0
# The port to use for the local web browser (to view molecules in NGL). Make sure nobody else is using it already!
webPort='8882'
# The name of a Slurm partition allowing jobs to run for up to 2 hours with 4 cores
shortQ='short'
longQ='infinite'
# The desired isodensity surface to use for viewing potential energy surfaces (a.u)
isoSurf=0.001

# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Maximum number of charges to fit per atom (minimum is fixed at 1)
maxAChg=4

natm=10
nfrag = 4

minMChg=10
maxMChg=40

# Define fragments using atom numbering from NGL window at top of notebook
frags=[[9, 10, 4],[3,8],[7,2],[5,1,6]]
# Minimum number of charges to fit for each fragment (can average fewer than 1 per atom)
minFChg=[3,2,2,3]
# Maximum number of charges to fit for each fragment (upper limit per atom fixed by maxAChg)
maxFChg=[12,8,8,12]

workdir = projDir + '/'
refdir = workdir + 'ref/'
htmldir = workdir + 'html/'
bindir = refBinDir + '/'
pdbfile = refdir + 'mol.pdb'
densCube = refdir + os.path.basename(refDensCube)
potCube = refdir + os.path.basename(refPotCube)

# %%
pydcm = Pydcm(projDir, refBinDir, refDensCube, refPotCube, webPort, frags, minFChg, maxFChg, maxAChg, minMChg, maxMChg, shortQ, longQ)

# %%
pydcm.make_ref_directory()
pydcm.start_server()
# Out:
# Changed to working directory /home/boittier/pydcm/models/fbutadiene-9/
# 10 atoms in molecule
# writing PDB file /home/boittier/pydcm/models/fbutadiene-9/ref/mol.pdb
#
# python /home/boittier/pydcm/bin/simple-cors-http-server.py 8882Running jobs:
# 0 : run_http()
#
# Web server running in directory /home/boittier/pydcm/models/fbutadiene-9, URLs are relative to this path
# If you change the project directory, you need to restart Jupyter-Lab to restart this server and create a new root for URLs

# %%
pydcm.show_ref_models()
# Out:
# ESP range: -0.034693 to 0.034693 a.u.
# 8882 /home/boittier/pydcm/models/fbutadiene-9/html/ /home/boittier/pydcm/models/fbutadiene-9/ref/mol.pdb
# http://localhost:8882/html/refESP.html
#         <iframe
#             width="1120"
#             height="750"
#             src="http://localhost:8882/html/refESP.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.display_mtpfit_comparison()
# Out:
# /home/boittier/pydcm/bin/mtpfit.py
#         <iframe
#             width="1120"
#             height="1550"
#             src="http://localhost:8882/html/mtpFit.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.do_atom_fit(maxAChg, ntry, nfrag)
# Out:
# ## 1Charges Per Atom:
# Atom 1 final RMSE: 4.827410584 kcal/mol
# Atom 2 final RMSE: 2.468260347 kcal/mol
# Atom 3 final RMSE: 6.277517592 kcal/mol
# Atom 4 final RMSE: 5.057776783 kcal/mol
# Atom 5 final RMSE: 1.750360648 kcal/mol
# Atom 6 final RMSE: 2.348276375 kcal/mol
# Atom 7 final RMSE: 1.571307057 kcal/mol
# Atom 8 final RMSE: 2.213722327 kcal/mol
# Atom 9 final RMSE: 1.880978813 kcal/mol
# Atom 10 final RMSE: 1.30054664 kcal/mol
#
# ## 2Charges Per Atom:
# Atom 1 final RMSE: 0.9404255525 kcal/mol
# Atom 2 final RMSE: 1.812421138 kcal/mol
# Atom 3 final RMSE: 1.191504107 kcal/mol
# Atom 4 final RMSE: 1.083496634 kcal/mol
# Atom 5 final RMSE: 0.6013072534 kcal/mol
# Atom 6 final RMSE: 0.4720284469 kcal/mol
# Atom 7 final RMSE: 1.35850901 kcal/mol
# Atom 8 final RMSE: 0.9057239228 kcal/mol
# Atom 9 final RMSE: 0.8298613575 kcal/mol
# Atom 10 final RMSE: 0.9012656993 kcal/mol
#
# ## 3Charges Per Atom:
# Atom 1 final RMSE: 0.2144283201 kcal/mol
# Atom 2 final RMSE: 0.2713184562 kcal/mol
# Atom 3 final RMSE: 0.4536945589 kcal/mol
# Atom 4 final RMSE: 0.1684029351 kcal/mol
# Atom 5 final RMSE: 0.2499574918 kcal/mol
# Atom 6 final RMSE: 0.1844314947 kcal/mol
# Atom 7 final RMSE: 0.2255715736 kcal/mol
# Atom 8 final RMSE: 0.1534760538 kcal/mol
# Atom 9 final RMSE: 0.3104275728 kcal/mol
# Atom 10 final RMSE: 0.1977080437 kcal/mol
#
# ## 4Charges Per Atom:
# Atom 1 final RMSE: 0.1209790357 kcal/mol
# Atom 2 final RMSE: 0.108898481 kcal/mol
# Atom 3 final RMSE: 0.1103549503 kcal/mol
# Atom 4 final RMSE: 0.09611131025 kcal/mol
# Atom 5 final RMSE: 0.05446139635 kcal/mol
# Atom 6 final RMSE: 0.1078643204 kcal/mol
# Atom 7 final RMSE: 0.05470896037 kcal/mol
# Atom 8 final RMSE: 0.09302417617 kcal/mol
# Atom 9 final RMSE: 0.07785188383 kcal/mol
# Atom 10 final RMSE: 0.05589108713 kcal/mol

# %%
# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Number of separate fits to perform (restarting a fit can lead to a better outcome). Cost scales linearly
nfit=2

pydcm.fit_fragments(ntry, nfit)
# Out:
# Frag 1 fit 1, 10 charges: Job 3483068 is still running
# Frag 1 fit 1, 11 charges: Job 3483069 is still running
# Frag 1 fit 1, 12 charges: Job 3483070 is still running
# Frag 1 fit 1, 13 charges: Job 3483071 is still running
# Frag 1 fit 2, 10 charges: Job 3483072 is still running
# Frag 1 fit 2, 11 charges: Job 3483073 is still running
# Frag 1 fit 2, 12 charges: Job 3483074 is still running
# Frag 1 fit 2, 13 charges: Job 3483075 is still running
# Frag 4 fit 1, 13 charges: Job 3483076 is still running
# Frag 4 fit 2, 13 charges: Job 3483077 is still running
#
# Summary of results:
# Frag 1, Fit 1, 3 charges, RMSE: 0.2699104524 kcal/mol
# Frag 1, Fit 1, 4 charges, RMSE: 0.2988500214 kcal/mol
# Frag 1, Fit 1, 5 charges, RMSE: 0.2825317283 kcal/mol
# Frag 1, Fit 1, 6 charges, RMSE: 0.1457442614 kcal/mol
# Frag 1, Fit 1, 7 charges, RMSE: 0.1959755773 kcal/mol
# Frag 1, Fit 1, 8 charges, RMSE: 0.1418509036 kcal/mol
# Frag 1, Fit 2, 3 charges, RMSE: 0.2699104525 kcal/mol
# Frag 1, Fit 2, 4 charges, RMSE: 0.2323971257 kcal/mol
# Frag 1, Fit 2, 5 charges, RMSE: 0.2222512378 kcal/mol
# Frag 1, Fit 2, 6 charges, RMSE: 0.3059188 kcal/mol
# Frag 1, Fit 2, 7 charges, RMSE: 0.1795796692 kcal/mol
# Frag 1, Fit 2, 8 charges, RMSE: 0.2732908319 kcal/mol
# Frag 2, Fit 1, 2 charges, RMSE: 1.81354794 kcal/mol
# Frag 2, Fit 1, 3 charges, RMSE: 0.3220999815 kcal/mol
# Frag 2, Fit 1, 4 charges, RMSE: 0.1822961795 kcal/mol
# Frag 2, Fit 1, 5 charges, RMSE: 0.1382154293 kcal/mol
# Frag 2, Fit 1, 6 charges, RMSE: 0.05815248858 kcal/mol
# Frag 2, Fit 1, 7 charges, RMSE: 0.0538765572 kcal/mol
# Frag 2, Fit 1, 8 charges, RMSE: 0.0542502971 kcal/mol
# Frag 2, Fit 2, 2 charges, RMSE: 1.81354794 kcal/mol
# Frag 2, Fit 2, 3 charges, RMSE: 0.3220999817 kcal/mol
# Frag 2, Fit 2, 4 charges, RMSE: 0.29176297 kcal/mol
# Frag 2, Fit 2, 5 charges, RMSE: 0.1409841752 kcal/mol
# Frag 2, Fit 2, 6 charges, RMSE: 0.04683247388 kcal/mol
# Frag 2, Fit 2, 7 charges, RMSE: 0.05310875856 kcal/mol
# Frag 2, Fit 2, 8 charges, RMSE: 0.051469371 kcal/mol
# Frag 3, Fit 1, 2 charges, RMSE: 1.217587664 kcal/mol
# Frag 3, Fit 1, 3 charges, RMSE: 0.8030552171 kcal/mol
# Frag 3, Fit 1, 4 charges, RMSE: 0.3262678852 kcal/mol
# Frag 3, Fit 1, 5 charges, RMSE: 0.3163732319 kcal/mol
# Frag 3, Fit 1, 6 charges, RMSE: 0.2392817072 kcal/mol
# Frag 3, Fit 1, 7 charges, RMSE: 0.08007263068 kcal/mol
# Frag 3, Fit 1, 8 charges, RMSE: 0.07099074456 kcal/mol
# Frag 3, Fit 2, 2 charges, RMSE: 1.217587664 kcal/mol
# Frag 3, Fit 2, 3 charges, RMSE: 0.8030552172 kcal/mol
# Frag 3, Fit 2, 4 charges, RMSE: 0.3262678923 kcal/mol
# Frag 3, Fit 2, 5 charges, RMSE: 0.2446281926 kcal/mol
# Frag 3, Fit 2, 6 charges, RMSE: 0.153748118 kcal/mol
# Frag 3, Fit 2, 7 charges, RMSE: 0.0943388583 kcal/mol
# Frag 3, Fit 2, 8 charges, RMSE: 0.07020639017 kcal/mol
# Frag 4, Fit 1, 3 charges, RMSE: 0.3880345501 kcal/mol
# Frag 4, Fit 1, 4 charges, RMSE: 0.2814597959 kcal/mol
# Frag 4, Fit 1, 5 charges, RMSE: 0.2782590196 kcal/mol
# Frag 4, Fit 1, 6 charges, RMSE: 0.277419706 kcal/mol
# Frag 4, Fit 1, 7 charges, RMSE: 0.080719964 kcal/mol
# Frag 4, Fit 1, 8 charges, RMSE: 0.06333782958 kcal/mol
# Frag 4, Fit 1, 9 charges, RMSE: 0.05635873817 kcal/mol
# Frag 4, Fit 1, 10 charges, RMSE: 0.03236493695 kcal/mol
# Frag 4, Fit 1, 11 charges, RMSE: 0.0446681325 kcal/mol
# Frag 4, Fit 2, 3 charges, RMSE: 0.2485216089 kcal/mol
# Frag 4, Fit 2, 4 charges, RMSE: 0.2814597947 kcal/mol
# Frag 4, Fit 2, 5 charges, RMSE: 0.2603456298 kcal/mol
# Frag 4, Fit 2, 6 charges, RMSE: 0.1782990682 kcal/mol
# Frag 4, Fit 2, 7 charges, RMSE: 0.2818138844 kcal/mol
# Frag 4, Fit 2, 8 charges, RMSE: 0.1117170806 kcal/mol
# Frag 4, Fit 2, 9 charges, RMSE: 0.04450779869 kcal/mol
# Frag 4, Fit 2, 10 charges, RMSE: 0.05227733578 kcal/mol
# Frag 4, Fit 2, 11 charges, RMSE: 0.07781047595 kcal/mol

# %%
pydcm.combine_fragements(ntry, nfit)
# Out:
# 10 CHARGES:
# NEW BEST 10 charges: 3 2 2 3 rmse = 0.8873919163249999
# 11 CHARGES:
# NEW BEST 11 charges: 3 2 2 4 rmse = 0.8956264627749999
# NEW BEST 11 charges: 3 2 3 3 rmse = 0.7837588045999999
# NEW BEST 11 charges: 3 3 2 3 rmse = 0.5145299267000001
# 12 CHARGES:
# NEW BEST 12 charges: 3 2 2 5 rmse = 0.8903479215499999
# NEW BEST 12 charges: 3 2 3 4 rmse = 0.7919933510499999
# NEW BEST 12 charges: 3 2 4 3 rmse = 0.664561971625
# NEW BEST 12 charges: 3 3 2 4 rmse = 0.5227644731500001
# NEW BEST 12 charges: 3 3 3 3 rmse = 0.410896814975
# 13 CHARGES:
# NEW BEST 13 charges: 3 2 2 6 rmse = 0.8698362811499999
# NEW BEST 13 charges: 3 2 3 5 rmse = 0.7867148098249999
# NEW BEST 13 charges: 3 2 4 4 rmse = 0.672796518075
# NEW BEST 13 charges: 3 2 5 3 rmse = 0.644152048475
# NEW BEST 13 charges: 3 3 2 5 rmse = 0.517485931925
# NEW BEST 13 charges: 3 3 3 4 rmse = 0.419131361425
# NEW BEST 13 charges: 3 3 4 3 rmse = 0.291699982
# 14 CHARGES:
# NEW BEST 14 charges: 3 2 2 7 rmse = 0.8454415050999999
# NEW BEST 14 charges: 3 2 3 6 rmse = 0.7662031694249999
# NEW BEST 14 charges: 3 2 4 5 rmse = 0.6675179768499999
# NEW BEST 14 charges: 3 2 5 4 rmse = 0.652386594925
# NEW BEST 14 charges: 3 2 6 3 rmse = 0.621432029825
# NEW BEST 14 charges: 3 3 2 6 rmse = 0.49697429152500006
# NEW BEST 14 charges: 3 3 3 5 rmse = 0.4138528202
# NEW BEST 14 charges: 3 3 4 4 rmse = 0.29993452845
# NEW BEST 14 charges: 3 3 5 3 rmse = 0.27129005885
# NEW BEST 14 charges: 3 4 4 3 rmse = 0.2567490315
# 15 CHARGES:
# NEW BEST 15 charges: 3 2 2 8 rmse = 0.8410959714949999
# NEW BEST 15 charges: 3 2 3 7 rmse = 0.7418083933749999
# NEW BEST 15 charges: 3 2 4 6 rmse = 0.6470063364499999
# NEW BEST 15 charges: 3 2 6 4 rmse = 0.629666576275
# NEW BEST 15 charges: 3 2 7 3 rmse = 0.603013157995
# NEW BEST 15 charges: 3 3 2 7 rmse = 0.47257951547500004
# NEW BEST 15 charges: 3 3 3 6 rmse = 0.39334117980000005
# NEW BEST 15 charges: 3 3 4 5 rmse = 0.294655987225
# NEW BEST 15 charges: 3 3 5 4 rmse = 0.2795246053
# NEW BEST 15 charges: 3 3 6 3 rmse = 0.2485700402
# NEW BEST 15 charges: 3 4 5 3 rmse = 0.23633910835
# 16 CHARGES:
# NEW BEST 16 charges: 3 2 2 9 rmse = 0.8363884637725
# NEW BEST 16 charges: 3 2 3 8 rmse = 0.7374628597699999
# NEW BEST 16 charges: 3 2 4 7 rmse = 0.6226115604
# NEW BEST 16 charges: 3 2 7 4 rmse = 0.611247704445
# NEW BEST 16 charges: 3 2 8 3 rmse = 0.6005465978675
# NEW BEST 16 charges: 3 3 2 8 rmse = 0.46823398187000004
# NEW BEST 16 charges: 3 3 3 7 rmse = 0.36894640375000004
# NEW BEST 16 charges: 3 3 4 6 rmse = 0.27414434682500005
# NEW BEST 16 charges: 3 3 6 4 rmse = 0.25680458665
# NEW BEST 16 charges: 3 3 7 3 rmse = 0.23015116837000002
# NEW BEST 16 charges: 3 4 6 3 rmse = 0.2136190897
# 17 CHARGES:
# NEW BEST 17 charges: 3 2 2 10 rmse = 0.8333527483375
# NEW BEST 17 charges: 3 2 3 9 rmse = 0.7327553520475
# NEW BEST 17 charges: 3 2 4 8 rmse = 0.618266026795
# NEW BEST 17 charges: 3 2 5 7 rmse = 0.60220163725
# NEW BEST 17 charges: 3 3 2 9 rmse = 0.46352647414750003
# NEW BEST 17 charges: 3 3 3 8 rmse = 0.36460087014500003
# NEW BEST 17 charges: 3 3 4 7 rmse = 0.24974957077500004
# NEW BEST 17 charges: 3 3 7 4 rmse = 0.23838571482000004
# NEW BEST 17 charges: 3 3 8 3 rmse = 0.2276846082425
# NEW BEST 17 charges: 3 4 6 4 rmse = 0.22185363614999998
# NEW BEST 17 charges: 3 4 7 3 rmse = 0.19520021787
# 18 CHARGES:
# NEW BEST 18 charges: 3 2 2 11 rmse = 0.8364285472249999
# NEW BEST 18 charges: 3 2 3 10 rmse = 0.7297196366124999
# NEW BEST 18 charges: 3 2 4 9 rmse = 0.6135585190725
# NEW BEST 18 charges: 3 2 5 8 rmse = 0.597856103645
# NEW BEST 18 charges: 3 2 6 7 rmse = 0.5794816186
# NEW BEST 18 charges: 3 3 2 10 rmse = 0.46049075871250006
# NEW BEST 18 charges: 3 3 3 9 rmse = 0.35989336242250003
# NEW BEST 18 charges: 3 3 4 8 rmse = 0.24540403717000003
# NEW BEST 18 charges: 3 3 5 7 rmse = 0.22933964762500003
# NEW BEST 18 charges: 3 4 4 7 rmse = 0.21479862027500002
# NEW BEST 18 charges: 3 4 7 4 rmse = 0.20343476432000002
# NEW BEST 18 charges: 3 4 8 3 rmse = 0.19273365774249998
# NEW BEST 18 charges: 3 5 7 3 rmse = 0.18418003032
# NEW BEST 18 charges: 3 6 6 3 rmse = 0.179753163295
# 19 CHARGES:
# NEW BEST 19 charges: 3 2 2 12 rmse = 25000.5752615141
# NEW BEST 19 charges: 3 2 3 11 rmse = 0.7327954354999999
# NEW BEST 19 charges: 3 2 4 10 rmse = 0.6105228036375
# NEW BEST 19 charges: 3 2 5 9 rmse = 0.5931485959225
# NEW BEST 19 charges: 3 2 6 8 rmse = 0.575136084995
# NEW BEST 19 charges: 3 2 7 7 rmse = 0.56106274677
# NEW BEST 19 charges: 3 3 2 11 rmse = 0.46356655760000004
# NEW BEST 19 charges: 3 3 3 10 rmse = 0.35685764698750005
# NEW BEST 19 charges: 3 3 4 9 rmse = 0.24069652944750003
# NEW BEST 19 charges: 3 3 5 8 rmse = 0.22499411402000002
# NEW BEST 19 charges: 3 3 6 7 rmse = 0.20661962897500002
# NEW BEST 19 charges: 3 4 5 7 rmse = 0.194388697125
# NEW BEST 19 charges: 3 5 7 4 rmse = 0.19241457677
# NEW BEST 19 charges: 3 5 8 3 rmse = 0.18171347019249998
# NEW BEST 19 charges: 3 6 7 3 rmse = 0.161334291465
# 20 CHARGES:
# NEW BEST 20 charges: 3 2 3 12 rmse = 25000.471628402374
# NEW BEST 20 charges: 3 2 4 11 rmse = 0.613598602525
# NEW BEST 20 charges: 3 2 5 10 rmse = 0.5901128804875
# NEW BEST 20 charges: 3 2 6 9 rmse = 0.5704285772725001
# NEW BEST 20 charges: 3 2 7 8 rmse = 0.556717213165
# NEW BEST 20 charges: 3 3 3 11 rmse = 0.35993344587500004
# NEW BEST 20 charges: 3 3 4 10 rmse = 0.23766081401250003
# NEW BEST 20 charges: 3 3 5 9 rmse = 0.22028660629750002
# NEW BEST 20 charges: 3 3 6 8 rmse = 0.20227409537000002
# NEW BEST 20 charges: 3 3 7 7 rmse = 0.18820075714500004
# NEW BEST 20 charges: 3 4 6 7 rmse = 0.171668678475
# NEW BEST 20 charges: 3 6 7 4 rmse = 0.169568837915
# NEW BEST 20 charges: 3 6 8 3 rmse = 0.15886773133749998
# NEW BEST 20 charges: 4 6 7 3 rmse = 0.15195595979
# 21 CHARGES:
# NEW BEST 21 charges: 3 2 4 12 rmse = 25000.3524315694
# NEW BEST 21 charges: 3 2 5 11 rmse = 0.593188679375
# NEW BEST 21 charges: 3 2 6 10 rmse = 0.5673928618375
# NEW BEST 21 charges: 3 2 7 9 rmse = 0.5520097054425
# NEW BEST 21 charges: 3 3 4 11 rmse = 0.24073661290000004
# NEW BEST 21 charges: 3 3 5 10 rmse = 0.21725089086250002
# NEW BEST 21 charges: 3 3 6 9 rmse = 0.1975665876475
# NEW BEST 21 charges: 3 3 7 8 rmse = 0.18385522354000003
# NEW BEST 21 charges: 3 4 6 8 rmse = 0.16732314487
# NEW BEST 21 charges: 3 4 7 7 rmse = 0.15324980664500001
# NEW BEST 21 charges: 4 6 8 3 rmse = 0.1494893996625
# NEW BEST 21 charges: 5 6 7 3 rmse = 0.149419487815
# NEW BEST 21 charges: 6 6 6 3 rmse = 0.14871161554499998
# 22 CHARGES:
# NEW BEST 22 charges: 3 2 5 12 rmse = 25000.33202164625
# NEW BEST 22 charges: 3 2 6 11 rmse = 0.570468660725
# NEW BEST 22 charges: 3 2 7 10 rmse = 0.5489739900075
# NEW BEST 22 charges: 3 3 5 11 rmse = 0.22032668975000003
# NEW BEST 22 charges: 3 3 6 10 rmse = 0.1945308722125
# NEW BEST 22 charges: 3 3 7 9 rmse = 0.17914771581750003
# NEW BEST 22 charges: 3 4 6 9 rmse = 0.1626156371475
# NEW BEST 22 charges: 3 4 7 8 rmse = 0.14890427304
# NEW BEST 22 charges: 3 5 7 7 rmse = 0.142229619095
# NEW BEST 22 charges: 3 6 6 7 rmse = 0.13780275207
# NEW BEST 22 charges: 6 6 7 3 rmse = 0.130292743715
# 23 CHARGES:
# NEW BEST 23 charges: 3 2 6 12 rmse = 25000.3093016276
# NEW BEST 23 charges: 3 2 7 11 rmse = 0.552049788895
# NEW BEST 23 charges: 3 2 8 10 rmse = 0.54650742988
# NEW BEST 23 charges: 3 3 6 11 rmse = 0.19760667110000002
# NEW BEST 23 charges: 3 3 7 10 rmse = 0.17611200038250002
# NEW BEST 23 charges: 3 4 6 10 rmse = 0.1595799217125
# NEW BEST 23 charges: 3 4 7 9 rmse = 0.1441967653175
# NEW BEST 23 charges: 3 5 7 8 rmse = 0.13788408549
# NEW BEST 23 charges: 3 6 6 8 rmse = 0.133457218465
# NEW BEST 23 charges: 3 6 7 7 rmse = 0.11938388024000002
# 24 CHARGES:
# NEW BEST 24 charges: 3 2 7 12 rmse = 25000.29088275577
# NEW BEST 24 charges: 3 2 8 11 rmse = 0.5495832287675
# NEW BEST 24 charges: 3 3 7 11 rmse = 0.17918779927000003
# NEW BEST 24 charges: 3 3 8 10 rmse = 0.173645440255
# NEW BEST 24 charges: 3 4 6 11 rmse = 0.1626557206
# NEW BEST 24 charges: 3 4 7 10 rmse = 0.1411610498825
# NEW BEST 24 charges: 3 5 7 9 rmse = 0.1331765777675
# NEW BEST 24 charges: 3 6 6 9 rmse = 0.1287497107425
# NEW BEST 24 charges: 3 6 7 8 rmse = 0.11503834663500001
# NEW BEST 24 charges: 4 6 7 7 rmse = 0.11000554856500003
# 25 CHARGES:
# NEW BEST 25 charges: 3 2 8 12 rmse = 25000.288416195643
# NEW BEST 25 charges: 3 3 7 12 rmse = 24999.918020766145
# NEW BEST 25 charges: 3 3 8 11 rmse = 0.17672123914250001
# NEW BEST 25 charges: 3 4 7 11 rmse = 0.14423684877
# NEW BEST 25 charges: 3 4 8 10 rmse = 0.13869448975499998
# NEW BEST 25 charges: 3 5 7 10 rmse = 0.1301408623325
# NEW BEST 25 charges: 3 6 6 10 rmse = 0.1257139953075
# NEW BEST 25 charges: 3 6 7 9 rmse = 0.1103308389125
# NEW BEST 25 charges: 4 6 7 8 rmse = 0.10566001496000002
# 26 CHARGES:
# NEW BEST 26 charges: 3 3 8 12 rmse = 24999.915554206018
# NEW BEST 26 charges: 3 4 7 12 rmse = 24999.883069815645
# NEW BEST 26 charges: 3 4 8 11 rmse = 0.1417702886425
# NEW BEST 26 charges: 3 5 7 11 rmse = 0.13321666122
# NEW BEST 26 charges: 3 5 8 10 rmse = 0.12767430220499998
# NEW BEST 26 charges: 3 6 7 10 rmse = 0.1072951234775
# NEW BEST 26 charges: 4 6 7 9 rmse = 0.10095250723750002
# NEW BEST 26 charges: 6 6 7 7 rmse = 0.08834233249000001
# 27 CHARGES:
# NEW BEST 27 charges: 3 4 8 12 rmse = 24999.88060325552
# NEW BEST 27 charges: 3 5 7 12 rmse = 24999.872049628095
# NEW BEST 27 charges: 3 5 8 11 rmse = 0.1307501010925
# NEW BEST 27 charges: 3 6 7 11 rmse = 0.11037092236500001
# NEW BEST 27 charges: 3 6 8 10 rmse = 0.10482856334999999
# NEW BEST 27 charges: 4 6 7 10 rmse = 0.09791679180250001
# NEW BEST 27 charges: 6 6 6 9 rmse = 0.09770816299249999
# NEW BEST 27 charges: 6 6 7 8 rmse = 0.083996798885
# 28 CHARGES:
# NEW BEST 28 charges: 3 5 8 12 rmse = 24999.869583067968
# NEW BEST 28 charges: 3 6 7 12 rmse = 24999.84920388924
# NEW BEST 28 charges: 3 6 8 11 rmse = 0.1079043622375
# NEW BEST 28 charges: 3 7 8 10 rmse = 0.10639763451999998
# NEW BEST 28 charges: 4 6 7 11 rmse = 0.10099259069000002
# NEW BEST 28 charges: 4 6 8 10 rmse = 0.095450231675
# NEW BEST 28 charges: 5 6 7 10 rmse = 0.0953803198275
# NEW BEST 28 charges: 6 6 6 10 rmse = 0.09467244755749998
# NEW BEST 28 charges: 6 6 7 9 rmse = 0.0792892911625
# 29 CHARGES:
# NEW BEST 29 charges: 3 6 8 12 rmse = 24999.846737329113
# NEW BEST 29 charges: 3 7 8 11 rmse = 0.10947343340749999
# NEW BEST 29 charges: 3 8 8 10 rmse = 0.10598778763
# NEW BEST 29 charges: 4 6 8 11 rmse = 0.0985260305625
# NEW BEST 29 charges: 4 7 8 10 rmse = 0.09701930284499999
# NEW BEST 29 charges: 5 6 8 10 rmse = 0.09291375969999999
# NEW BEST 29 charges: 6 6 7 10 rmse = 0.0762535757275
# 30 CHARGES:
# NEW BEST 30 charges: 3 7 8 12 rmse = 24999.848306400283
# NEW BEST 30 charges: 3 8 8 11 rmse = 0.1090635865175
# NEW BEST 30 charges: 4 7 8 11 rmse = 0.1000951017325
# NEW BEST 30 charges: 4 8 8 10 rmse = 0.096609455955
# NEW BEST 30 charges: 5 6 8 11 rmse = 0.0959895585875
# NEW BEST 30 charges: 5 7 8 10 rmse = 0.09448283086999998
# NEW BEST 30 charges: 6 6 7 11 rmse = 0.079329374615
# NEW BEST 30 charges: 6 6 8 10 rmse = 0.07378701559999999
# 31 CHARGES:
# NEW BEST 31 charges: 3 8 8 12 rmse = 24999.847896553394
# NEW BEST 31 charges: 4 7 8 12 rmse = 24999.838928068606
# NEW BEST 31 charges: 4 8 8 11 rmse = 0.09968525484250002
# NEW BEST 31 charges: 5 7 8 11 rmse = 0.09755862975749999
# NEW BEST 31 charges: 5 8 8 10 rmse = 0.09407298398
# NEW BEST 31 charges: 6 6 8 11 rmse = 0.0768628144875
# NEW BEST 31 charges: 6 7 8 10 rmse = 0.07535608677
# NEW BEST 31 charges: 8 6 7 10 rmse = 0.0752802362775
# 32 CHARGES:
# NEW BEST 32 charges: 4 8 8 12 rmse = 24999.838518221717
# NEW BEST 32 charges: 5 7 8 12 rmse = 24999.836391596633
# NEW BEST 32 charges: 5 8 8 11 rmse = 0.0971487828675
# NEW BEST 32 charges: 6 7 8 11 rmse = 0.0784318856575
# NEW BEST 32 charges: 6 8 8 10 rmse = 0.07494623987999999
# NEW BEST 32 charges: 8 6 8 10 rmse = 0.07281367614999999
# 33 CHARGES:
# NEW BEST 33 charges: 5 8 8 12 rmse = 24999.835981749744
# NEW BEST 33 charges: 6 7 8 12 rmse = 24999.817264852532
# NEW BEST 33 charges: 6 8 8 11 rmse = 0.0780220387675
# NEW BEST 33 charges: 8 6 8 11 rmse = 0.0758894750375
# NEW BEST 33 charges: 8 7 8 10 rmse = 0.07438274732
# 34 CHARGES:
# NEW BEST 34 charges: 6 8 8 12 rmse = 24999.816855005643
# NEW BEST 34 charges: 7 8 8 11 rmse = 0.08648089071750001
# NEW BEST 34 charges: 8 7 8 11 rmse = 0.0774585462075
# NEW BEST 34 charges: 8 8 8 10 rmse = 0.07397290042999999
# 35 CHARGES:
# NEW BEST 35 charges: 7 8 8 12 rmse = 24999.825313857593
# NEW BEST 35 charges: 8 7 8 12 rmse = 24999.81629151308
# NEW BEST 35 charges: 8 8 8 11 rmse = 0.0770486993175
# 36 CHARGES:
# NEW BEST 36 charges: 8 8 8 12 rmse = 24999.815881666193
# NEW BEST 36 charges: 9 8 8 11 rmse = 24999.791585973417
# NEW BEST 36 charges: 10 8 8 10 rmse = 24999.78851017453
# NEW BEST 36 charges: 12 6 8 10 rmse = 24999.78735095025
# 37 CHARGES:
# NEW BEST 37 charges: 9 8 8 12 rmse = 49999.530418940296
# NEW BEST 37 charges: 10 8 8 11 rmse = 24999.791585973417
# NEW BEST 37 charges: 11 8 8 10 rmse = 24999.78851017453
# 38 CHARGES:
# NEW BEST 38 charges: 10 8 8 12 rmse = 49999.530418940296
# NEW BEST 38 charges: 11 8 8 11 rmse = 24999.791585973417
# NEW BEST 38 charges: 12 8 8 10 rmse = 24999.78851017453
# 39 CHARGES:
# NEW BEST 39 charges: 11 8 8 12 rmse = 49999.530418940296
# NEW BEST 39 charges: 12 8 8 11 rmse = 24999.791585973417
# 40 CHARGES:
# NEW BEST 40 charges: 12 8 8 12 rmse = 49999.530418940296

# %%
pydcm.refine_models()
# Out:
# Job 3483219 has crashed, resubmitting
# submitted jobID 3484460
# Job 3483220 has crashed, resubmitting
# submitted jobID 3484461
# Job 3483221 has crashed, resubmitting
# submitted jobID 3484462
# Job 3483222 has crashed, resubmitting
# submitted jobID 3484463
# Job 3483223 has crashed, resubmitting
# submitted jobID 3484464
#
# Summary of results:
# 10 charges, RMSE: 0.9464500353 kcal/mol
# 11 charges, RMSE: 0.5992699024 kcal/mol
# 12 charges, RMSE: 0.5926943124 kcal/mol
# 13 charges, RMSE: 0.5452939319 kcal/mol
# 14 charges, RMSE: 0.5365796293 kcal/mol
# 15 charges, RMSE: 0.5234623138 kcal/mol
# 16 charges, RMSE: 0.5050731759 kcal/mol
# 17 charges, RMSE: 0.4973111133 kcal/mol
# 18 charges, RMSE: 0.4936272317 kcal/mol
# 19 charges, RMSE: 0.4981090976 kcal/mol
# 20 charges, RMSE: 0.4889563224 kcal/mol
# 21 charges, RMSE: 0.4813745388 kcal/mol
# 22 charges, RMSE: 0.4843167963 kcal/mol
# 23 charges, RMSE: 0.4916192797 kcal/mol
# 24 charges, RMSE: 0.4836865997 kcal/mol
# 25 charges, RMSE: 0.4843160729 kcal/mol
# 26 charges, RMSE: 0.4709685904 kcal/mol
# 27 charges, RMSE: 0.4749614499 kcal/mol
# 28 charges, RMSE: 0.4763672183 kcal/mol
# 29 charges, RMSE: 0.4759324564 kcal/mol
# 30 charges, RMSE: 0.4739028919 kcal/mol
# 31 charges, RMSE: 0.4736864804 kcal/mol
# 32 charges, RMSE: 0.4728782766 kcal/mol
# 33 charges, RMSE: 0.4729574592 kcal/mol
# 34 charges, RMSE: 0.4734572647 kcal/mol
# 35 charges, RMSE: 0.4734655462 kcal/mol
