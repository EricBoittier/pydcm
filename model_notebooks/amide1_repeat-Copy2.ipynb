# %%
import sys
ars_path = "/home/boittier/pydcm/"
sys.path.insert(1, ars_path)
from _pydcm import *

# %%
# The Gaussian-format cube file containing electron density:
refDensCube="/home/boittier/amide_dih/scan/1_1_new-0.chk.d.cube"
# The Gaussian-format cube file containing electrostatic potential energy:
refPotCube="/home/boittier/amide_dih/scan/1_1_new-0.chk.p.cube"
# The root folder for your fitting project
projDir="/home/boittier/pydcm/models/amide1_test2"
# The bin directory containing the MDCM scripts and programs
refBinDir="/home/boittier/pydcm/bin"
# The total charge of the molecule to be fitted (a.u.)
qtot=0.0
# The port to use for the local web browser (to view molecules in NGL). Make sure nobody else is using it already!
webPort='8884'
# The name of a Slurm partition allowing jobs to run for up to 2 hours with 4 cores
shortQ='vshort'
longQ='infinite'
# The desired isodensity surface to use for viewing potential energy surfaces (a.u)
isoSurf=0.001

# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Maximum number of charges to fit per atom (minimum is fixed at 1)
maxAChg=4

natm=12
nfrag = 2

minMChg=10
maxMChg=20

# Define fragments using atom numbering from NGL window at top of notebook
frags= [[1, 3, 11, 5, 2, 9], [8, 4, 10, 6, 12, 7]] 
# Minimum number of charges to fit for each fragment (can average fewer than 1 per atom)
minFChg=[5,5]
# Maximum number of charges to fit for each fragment (upper limit per atom fixed by maxAChg)
maxFChg=[10,10]

workdir = projDir + '/'
refdir = workdir + 'ref/'
htmldir = workdir + 'html/'
bindir = refBinDir + '/'
pdbfile = refdir + 'mol.pdb'
densCube = refdir + os.path.basename(refDensCube)
potCube = refdir + os.path.basename(refPotCube)

# %%
pydcm = Pydcm(projDir, refBinDir, refDensCube, refPotCube, webPort, frags, minFChg, maxFChg, maxAChg, minMChg, maxMChg, shortQ, longQ)

# %%
pydcm.make_ref_directory()
pydcm.start_server()
# Out:
# Changed to working directory /home/boittier/pydcm/models/amide1_test2/
# 12 atoms in molecule
# writing PDB file /home/boittier/pydcm/models/amide1_test2/ref/mol.pdb
#
# Running jobs:python /home/boittier/pydcm/bin/simple-cors-http-server.py 8884
# 0 : run_http()
#
#
# Web server running in directory /home/boittier/pydcm/models/amide1_test2, URLs are relative to this path
# If you change the project directory, you need to restart Jupyter-Lab to restart this server and create a new root for URLs

# %%
pydcm.show_ref_models()
# Out:
# ESP range: -0.0744605 to 0.0744605 a.u.
# 8884 /home/boittier/pydcm/models/amide1_test2/html/ /home/boittier/pydcm/models/amide1_test2/ref/mol.pdb
# http://localhost:8884/html/refESP.html
#         <iframe
#             width="1120"
#             height="750"
#             src="http://localhost:8884/html/refESP.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.display_mtpfit_comparison()
# Out:
# /home/boittier/pydcm/bin/mtpfit.py
#         <iframe
#             width="1120"
#             height="1550"
#             src="http://localhost:8884/html/mtpFit.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.do_atom_fit(maxAChg, ntry, nfrag)
# Out:
# ## 1Charges Per Atom:
# Atom 1 final RMSE: 1.21950337 kcal/mol
# Atom 2 final RMSE: 1.830239976 kcal/mol
# Atom 3 final RMSE: 2.624065495 kcal/mol
# Atom 4 final RMSE: 1.696052824 kcal/mol
# Atom 5 final RMSE: 1.228137299 kcal/mol
# Atom 6 final RMSE: 2.361341559 kcal/mol
# Atom 7 final RMSE: 2.241246934 kcal/mol
# Atom 8 final RMSE: 1.96492049 kcal/mol
# Atom 9 final RMSE: 3.333849151 kcal/mol
# Atom 10 final RMSE: 1.045708706 kcal/mol
# Atom 11 final RMSE: 2.8683054 kcal/mol
# Atom 12 final RMSE: 1.872155087 kcal/mol
#
# ## 2Charges Per Atom:
# Atom 1 final RMSE: 0.2273226512 kcal/mol
# Atom 2 final RMSE: 0.5728968496 kcal/mol
# Atom 3 final RMSE: 1.693168425 kcal/mol
# Atom 4 final RMSE: 0.2221944424 kcal/mol
# Atom 5 final RMSE: 0.6687556578 kcal/mol
# Atom 6 final RMSE: 0.3870685594 kcal/mol
# Atom 7 final RMSE: 0.303935719 kcal/mol
# Atom 8 final RMSE: 0.6397513788 kcal/mol
# Atom 9 final RMSE: 0.2335507558 kcal/mol
# Atom 10 final RMSE: 0.461763332 kcal/mol
# Atom 11 final RMSE: 0.2312597945 kcal/mol
# Atom 12 final RMSE: 0.4471743556 kcal/mol
#
# ## 3Charges Per Atom:
# Atom 1 final RMSE: 0.1669868198 kcal/mol
# Atom 2 final RMSE: 0.09021498858 kcal/mol
# Atom 3 final RMSE: 0.6832533413 kcal/mol
# Atom 4 final RMSE: 0.1105065835 kcal/mol
# Atom 5 final RMSE: 0.2725884531 kcal/mol
# Atom 6 final RMSE: 0.179712635 kcal/mol
# Atom 7 final RMSE: 0.04934739965 kcal/mol
# Atom 8 final RMSE: 0.1976166295 kcal/mol
# Atom 9 final RMSE: 0.1475983642 kcal/mol
# Atom 10 final RMSE: 0.2553751381 kcal/mol
# Atom 11 final RMSE: 0.1352291203 kcal/mol
# Atom 12 final RMSE: 0.1553316844 kcal/mol
#
# ## 4Charges Per Atom:
# Atom 1 final RMSE: 0.1199940322 kcal/mol
# Atom 2 final RMSE: 0.02456257506 kcal/mol
# Atom 3 final RMSE: 0.1552046211 kcal/mol
# Atom 4 final RMSE: 0.0389972468 kcal/mol
# Atom 5 final RMSE: 0.08252914042 kcal/mol
# Atom 6 final RMSE: 0.1026910876 kcal/mol
# Atom 7 final RMSE: 0.03345163841 kcal/mol
# Atom 8 final RMSE: 0.09833334761 kcal/mol
# Atom 9 final RMSE: 0.09912512217 kcal/mol
# Atom 10 final RMSE: 0.1046597602 kcal/mol
# Atom 11 final RMSE: 0.1067553389 kcal/mol
# Atom 12 final RMSE: 0.1112819717 kcal/mol

# %%
# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=1
# Number of separate fits to perform (restarting a fit can lead to a better outcome). Cost scales linearly
nfit=1

pydcm.fit_fragments(ntry, nfit)
# Out:
# Summary of results:
# Frag 1, Fit 1, 5 charges, RMSE: 1.176026939 kcal/mol
# Frag 1, Fit 1, 6 charges, RMSE: 1.065224051 kcal/mol
# Frag 1, Fit 1, 7 charges, RMSE: 1.058201712 kcal/mol
# Frag 1, Fit 1, 8 charges, RMSE: 0.7023170859 kcal/mol
# Frag 1, Fit 1, 9 charges, RMSE: 0.7059921345 kcal/mol
# Frag 1, Fit 1, 10 charges, RMSE: 0.6521429877 kcal/mol
# Frag 2, Fit 1, 5 charges, RMSE: 0.9031645606 kcal/mol
# Frag 2, Fit 1, 6 charges, RMSE: 0.8821332035 kcal/mol
# Frag 2, Fit 1, 7 charges, RMSE: 1.051428942 kcal/mol
# Frag 2, Fit 1, 8 charges, RMSE: 0.5584170697 kcal/mol
# Frag 2, Fit 1, 9 charges, RMSE: 0.3917332064 kcal/mol
# Frag 2, Fit 1, 10 charges, RMSE: 0.4692475099 kcal/mol

# %%
pydcm.combine_fragements(ntry, nfit)
# Out:
# 10 CHARGES:
# NEW BEST 10 charges: 5 5 rmse = 1.0395957498000001
# 11 CHARGES:
# NEW BEST 11 charges: 5 6 rmse = 1.0290800712500001
# NEW BEST 11 charges: 6 5 rmse = 0.9841943058
# 12 CHARGES:
# NEW BEST 12 charges: 5 7 rmse = 1.1137279405
# NEW BEST 12 charges: 6 6 rmse = 0.97367862725
# 13 CHARGES:
# NEW BEST 13 charges: 5 8 rmse = 0.8672220043500001
# NEW BEST 13 charges: 8 5 rmse = 0.80274082325
# 14 CHARGES:
# NEW BEST 14 charges: 5 9 rmse = 0.7838800726999999
# 15 CHARGES:
# NEW BEST 15 charges: 5 10 rmse = 0.82263722445
# NEW BEST 15 charges: 6 9 rmse = 0.7284786287
# 16 CHARGES:
# NEW BEST 16 charges: 6 10 rmse = 0.76723578045
# NEW BEST 16 charges: 7 9 rmse = 0.7249674591999999
# NEW BEST 16 charges: 8 8 rmse = 0.6303670778
# 17 CHARGES:
# NEW BEST 17 charges: 7 10 rmse = 0.76372461095
# NEW BEST 17 charges: 8 9 rmse = 0.54702514615
# 18 CHARGES:
# NEW BEST 18 charges: 8 10 rmse = 0.5857822979
# NEW BEST 18 charges: 9 9 rmse = 0.5488626704499999
# 19 CHARGES:
# NEW BEST 19 charges: 9 10 rmse = 0.5876198222
# NEW BEST 19 charges: 10 9 rmse = 0.52193809705
# 20 CHARGES:
# NEW BEST 20 charges: 10 10 rmse = 0.5606952488

# %%
pydcm.refine_models()
# Out:
# Summary of results:
# 10 charges, RMSE: 1.114958856 kcal/mol
# 11 charges, RMSE: 1.076341966 kcal/mol
# 12 charges, RMSE: 1.034496864 kcal/mol
# 13 charges, RMSE: 1.004358762 kcal/mol
# 14 charges, RMSE: 0.9432520987 kcal/mol
# 15 charges, RMSE: 0.9224992173 kcal/mol
# 16 charges, RMSE: 0.798059041 kcal/mol
# 17 charges, RMSE: 0.7169496468 kcal/mol
# 18 charges, RMSE: 0.7961361816 kcal/mol
# 19 charges, RMSE: 0.7376643979 kcal/mol
# 20 charges, RMSE: 0.695189551 kcal/mol

# %%
pydcm.analyse_model(20)
# Out:
# Ditriantapole RMSE: 3.755583513E-01
# 0.04785159184
# Monopole RMSE: 7.862018826E-01
# 0.200108795
# satisfied
# Quadrupole RMSE: 3.760013802E-01
# 0.04814144426
# 20 charge model RMSE: 5.341354807E-01
# 0.1027991754
# [0.3755583513, 0.8013067605, 0.1203167341, 0.04785159184, 0.7862018826, 1.555775183, 0.501876414, 0.200108795, 0.3760013802, 0.8021196524, 0.1208510733, 0.04814144426, 0.5341354807, 1.099755579, 0.2702990527, 0.1027991754]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3dbc249b8741> in <module>
# ----> 1 pydcm.analyse_model(20)
#
# ~/pydcm/_pydcm.py in analyse_model(self, nchg, isoSurf)
#    1774
#    1775         # SHOW SLICES FROM R
# -> 1776         writeNGLHTML2('analyze.html', 'ref/' + os.path.basename(densCube), errorFiles[2],
#    1777                       'ref/' + os.path.basename(densCube),
#    1778                       cubeFiles[4], rmse, maxErr, npts, '6-analysis/' + moldir + '/comparison.png')
#
# NameError: name 'densCube' is not defined

# %%
pydcm.refinedir
