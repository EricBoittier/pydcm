# %%
import sys
ars_path = "/home/boittier/pydcm/"
sys.path.insert(1, ars_path)
from _pydcm import *

# %%
# The Gaussian-format cube file containing electron density:
refDensCube="/home/boittier/B.pdb/SCAN_1_2_3_4_S_36_10.0/5_SCAN/B.d.cube"
# The Gaussian-format cube file containing electrostatic potential energy:
refPotCube="/home/boittier/B.pdb/SCAN_1_2_3_4_S_36_10.0/5_SCAN/B.p.cube"
# The root folder for your fitting project
projDir="/home/boittier/pydcm/models/fbutadiene-5"
# The bin directory containing the MDCM scripts and programs
refBinDir="/home/boittier/pydcm/bin"
# The total charge of the molecule to be fitted (a.u.)
qtot=0.0
# The port to use for the local web browser (to view molecules in NGL). Make sure nobody else is using it already!
webPort='8886'
# The name of a Slurm partition allowing jobs to run for up to 2 hours with 4 cores
shortQ='vshort'
longQ='infinite'
# The desired isodensity surface to use for viewing potential energy surfaces (a.u)
isoSurf=0.001


# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Maximum number of charges to fit per atom (minimum is fixed at 1)
maxAChg=4

natm=10
nfrag = 4
minMChg=10
maxMChg=40

# Define fragments using atom numbering from NGL window at top of notebook
frags=[[9, 10, 4],[3,8],[7,2],[5,1,6]]
# Minimum number of charges to fit for each fragment (can average fewer than 1 per atom)
minFChg=[3,2,2,3]
# Maximum number of charges to fit for each fragment (upper limit per atom fixed by maxAChg)
maxFChg=[12,8,8,12]

workdir = projDir + '/'
refdir = workdir + 'ref/'
htmldir = workdir + 'html/'
bindir = refBinDir + '/'
pdbfile = refdir + 'mol.pdb'
densCube = refdir + os.path.basename(refDensCube)
potCube = refdir + os.path.basename(refPotCube)

# %%
pydcm = Pydcm(projDir, refBinDir, refDensCube, refPotCube, webPort, frags, minFChg, maxFChg, maxAChg, minMChg, maxMChg, shortQ, longQ)

# %%
pydcm.make_ref_directory()
pydcm.start_server()
# Out:
# Changed to working directory /home/boittier/pydcm/models/fbutadiene-5/
# 10 atoms in molecule
# writing PDB file /home/boittier/pydcm/models/fbutadiene-5/ref/mol.pdb
#
# Running jobs:python /home/boittier/pydcm/bin/simple-cors-http-server.py 8886
#
# 0 : run_http()
#
# Web server running in directory /home/boittier/pydcm/models/fbutadiene-5, URLs are relative to this path
# If you change the project directory, you need to restart Jupyter-Lab to restart this server and create a new root for URLs

# %%
pydcm.show_ref_models()
# Out:
# ESP range: -0.0335524 to 0.0335524 a.u.
# 8886 /home/boittier/pydcm/models/fbutadiene-5/html/ /home/boittier/pydcm/models/fbutadiene-5/ref/mol.pdb
# http://localhost:8886/html/refESP.html
#         <iframe
#             width="1120"
#             height="750"
#             src="http://localhost:8886/html/refESP.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.display_mtpfit_comparison()
# Out:
# /home/boittier/pydcm/bin/mtpfit.py
#         <iframe
#             width="1120"
#             height="1550"
#             src="http://localhost:8886/html/mtpFit.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pydcm.do_atom_fit(maxAChg, ntry, nfrag)
# Out:
# ## 1Charges Per Atom:
# Atom 1 final RMSE: 6.473822652 kcal/mol
# Atom 2 final RMSE: 2.190867046 kcal/mol
# Atom 3 final RMSE: 2.510778889 kcal/mol
# Atom 4 final RMSE: 3.574881405 kcal/mol
# Atom 5 final RMSE: 2.863805664 kcal/mol
# Atom 6 final RMSE: 3.329572405 kcal/mol
# Atom 7 final RMSE: 2.857980933 kcal/mol
# Atom 8 final RMSE: 1.298518964 kcal/mol
# Atom 9 final RMSE: 0.9563704538 kcal/mol
# Atom 10 final RMSE: 1.156858318 kcal/mol
#
# ## 2Charges Per Atom:
# Atom 1 final RMSE: 0.9320459798 kcal/mol
# Atom 2 final RMSE: 1.163357964 kcal/mol
# Atom 3 final RMSE: 0.7216571113 kcal/mol
# Atom 4 final RMSE: 0.8843868809 kcal/mol
# Atom 5 final RMSE: 0.5335073562 kcal/mol
# Atom 6 final RMSE: 0.2474697596 kcal/mol
# Atom 7 final RMSE: 0.7611986389 kcal/mol
# Atom 8 final RMSE: 1.069020952 kcal/mol
# Atom 9 final RMSE: 0.4761133231 kcal/mol
# Atom 10 final RMSE: 0.8656375353 kcal/mol
#
# ## 3Charges Per Atom:
# Atom 1 final RMSE: 0.2116592324 kcal/mol
# Atom 2 final RMSE: 0.1909277893 kcal/mol
# Atom 3 final RMSE: 0.425021799 kcal/mol
# Atom 4 final RMSE: 0.211531902 kcal/mol
# Atom 5 final RMSE: 0.2027868412 kcal/mol
# Atom 6 final RMSE: 0.1101942589 kcal/mol
# Atom 7 final RMSE: 0.3287587946 kcal/mol
# Atom 8 final RMSE: 0.4566240116 kcal/mol
# Atom 9 final RMSE: 0.1610280287 kcal/mol
# Atom 10 final RMSE: 0.4907680041 kcal/mol
#
# ## 4Charges Per Atom:
# Atom 1 final RMSE: 0.135216172 kcal/mol
# Atom 2 final RMSE: 0.09153616658 kcal/mol
# Atom 3 final RMSE: 0.1833736175 kcal/mol
# Atom 4 final RMSE: 0.1470577861 kcal/mol
# Atom 5 final RMSE: 0.07928236965 kcal/mol
# Atom 6 final RMSE: 0.08709943754 kcal/mol
# Atom 7 final RMSE: 0.07015434755 kcal/mol
# Atom 8 final RMSE: 0.1323495183 kcal/mol
# Atom 9 final RMSE: 0.04005223926 kcal/mol
# Atom 10 final RMSE: 0.09417425582 kcal/mol

# %%
# Number of refinement iterations for each fit. More is better, but each fit will take longer
ntry=4
# Number of separate fits to perform (restarting a fit can lead to a better outcome). Cost scales linearly
nfit=2

pydcm.fit_fragments(ntry, nfit)
# Out:
# Frag 1 fit 1, 11 charges: Job 3483781 is still running
# Frag 1 fit 1, 12 charges: Job 3483782 is still running
# Frag 1 fit 1, 13 charges: Job 3483783 is still running
# Frag 1 fit 2, 11 charges: Job 3483791 is still running
# Frag 1 fit 2, 12 charges: Job 3483792 is still running
# Frag 1 fit 2, 13 charges: Job 3483793 is still running
# Frag 4 fit 1, 12 charges: Job 3483830 is still running
# Frag 4 fit 1, 13 charges: Job 3483831 is still running
# Frag 4 fit 2, 11 charges: Job 3483839 is still running
# Frag 4 fit 2, 12 charges: Job 3483840 is still running
# Frag 4 fit 2, 13 charges: Job 3483841 is still running
#
# Summary of results:
# Frag 1, Fit 1, 3 charges, RMSE: 0.2691934113 kcal/mol
# Frag 1, Fit 1, 4 charges, RMSE: 0.2296820417 kcal/mol
# Frag 1, Fit 1, 5 charges, RMSE: 0.1786822344 kcal/mol
# Frag 1, Fit 1, 6 charges, RMSE: 0.163157026 kcal/mol
# Frag 1, Fit 1, 7 charges, RMSE: 0.1038030284 kcal/mol
# Frag 1, Fit 1, 8 charges, RMSE: 0.09982822087 kcal/mol
# Frag 1, Fit 1, 9 charges, RMSE: 0.07247099731 kcal/mol
# Frag 1, Fit 2, 3 charges, RMSE: 0.2691934111 kcal/mol
# Frag 1, Fit 2, 4 charges, RMSE: 0.229682042 kcal/mol
# Frag 1, Fit 2, 5 charges, RMSE: 0.2040281653 kcal/mol
# Frag 1, Fit 2, 6 charges, RMSE: 0.1677315358 kcal/mol
# Frag 1, Fit 2, 7 charges, RMSE: 0.1096722282 kcal/mol
# Frag 1, Fit 2, 8 charges, RMSE: 0.1285150069 kcal/mol
# Frag 1, Fit 2, 9 charges, RMSE: 0.1328837749 kcal/mol
# Frag 2, Fit 1, 2 charges, RMSE: 1.110908005 kcal/mol
# Frag 2, Fit 1, 3 charges, RMSE: 0.3555957174 kcal/mol
# Frag 2, Fit 1, 4 charges, RMSE: 0.2717289289 kcal/mol
# Frag 2, Fit 1, 5 charges, RMSE: 0.1594380273 kcal/mol
# Frag 2, Fit 1, 6 charges, RMSE: 0.113758898 kcal/mol
# Frag 2, Fit 1, 7 charges, RMSE: 0.1156768367 kcal/mol
# Frag 2, Fit 1, 8 charges, RMSE: 0.1047537356 kcal/mol
# Frag 2, Fit 2, 2 charges, RMSE: 1.110908005 kcal/mol
# Frag 2, Fit 2, 3 charges, RMSE: 0.3555957173 kcal/mol
# Frag 2, Fit 2, 4 charges, RMSE: 0.2163019616 kcal/mol
# Frag 2, Fit 2, 5 charges, RMSE: 0.1454423912 kcal/mol
# Frag 2, Fit 2, 6 charges, RMSE: 0.1137533113 kcal/mol
# Frag 2, Fit 2, 7 charges, RMSE: 0.1211517483 kcal/mol
# Frag 2, Fit 2, 8 charges, RMSE: 0.08571388485 kcal/mol
# Frag 3, Fit 1, 2 charges, RMSE: 0.9856936019 kcal/mol
# Frag 3, Fit 1, 3 charges, RMSE: 0.61019736 kcal/mol
# Frag 3, Fit 1, 4 charges, RMSE: 0.3145220848 kcal/mol
# Frag 3, Fit 1, 5 charges, RMSE: 0.2609224044 kcal/mol
# Frag 3, Fit 1, 6 charges, RMSE: 0.156707348 kcal/mol
# Frag 3, Fit 1, 7 charges, RMSE: 0.08572487375 kcal/mol
# Frag 3, Fit 1, 8 charges, RMSE: 0.07191022124 kcal/mol
# Frag 3, Fit 2, 2 charges, RMSE: 0.9856936021 kcal/mol
# Frag 3, Fit 2, 3 charges, RMSE: 0.6101973599 kcal/mol
# Frag 3, Fit 2, 4 charges, RMSE: 0.314522085 kcal/mol
# Frag 3, Fit 2, 5 charges, RMSE: 0.2515117339 kcal/mol
# Frag 3, Fit 2, 6 charges, RMSE: 0.1410153909 kcal/mol
# Frag 3, Fit 2, 7 charges, RMSE: 0.1182181391 kcal/mol
# Frag 3, Fit 2, 8 charges, RMSE: 0.07320374215 kcal/mol
# Frag 4, Fit 1, 3 charges, RMSE: 0.2559434653 kcal/mol
# Frag 4, Fit 1, 4 charges, RMSE: 0.2206607952 kcal/mol
# Frag 4, Fit 1, 5 charges, RMSE: 0.1981824183 kcal/mol
# Frag 4, Fit 1, 6 charges, RMSE: 0.1336766103 kcal/mol
# Frag 4, Fit 1, 7 charges, RMSE: 0.1203203198 kcal/mol
# Frag 4, Fit 1, 8 charges, RMSE: 0.08704079447 kcal/mol
# Frag 4, Fit 1, 9 charges, RMSE: 0.0651967623 kcal/mol
# Frag 4, Fit 1, 10 charges, RMSE: 0.049827616 kcal/mol
# Frag 4, Fit 2, 3 charges, RMSE: 0.2559434656 kcal/mol
# Frag 4, Fit 2, 4 charges, RMSE: 0.2110406648 kcal/mol
# Frag 4, Fit 2, 5 charges, RMSE: 0.1982002902 kcal/mol
# Frag 4, Fit 2, 6 charges, RMSE: 0.1357712562 kcal/mol
# Frag 4, Fit 2, 7 charges, RMSE: 0.1111674178 kcal/mol
# Frag 4, Fit 2, 8 charges, RMSE: 0.1052099665 kcal/mol
# Frag 4, Fit 2, 9 charges, RMSE: 0.06627127486 kcal/mol

# %%
pydcm.combine_fragements(ntry, nfit)
# Out:
# 10 CHARGES:
# NEW BEST 10 charges: 3 2 2 3 rmse = 0.655434620825
# 11 CHARGES:
# NEW BEST 11 charges: 3 2 2 4 rmse = 0.6442089207
# NEW BEST 11 charges: 3 2 3 3 rmse = 0.561560560325
# NEW BEST 11 charges: 3 3 2 3 rmse = 0.4666065489
# 12 CHARGES:
# NEW BEST 12 charges: 3 2 2 5 rmse = 0.640994359075
# NEW BEST 12 charges: 3 2 3 4 rmse = 0.5503348602
# NEW BEST 12 charges: 3 2 4 3 rmse = 0.48764174155000006
# NEW BEST 12 charges: 3 3 2 4 rmse = 0.455380848775
# NEW BEST 12 charges: 3 3 3 3 rmse = 0.37273248840000006
# 13 CHARGES:
# NEW BEST 13 charges: 3 2 2 6 rmse = 0.6248679070750001
# NEW BEST 13 charges: 3 2 3 5 rmse = 0.547120298575
# NEW BEST 13 charges: 3 2 4 4 rmse = 0.47641604142500005
# NEW BEST 13 charges: 3 2 5 3 rmse = 0.47188915382499996
# NEW BEST 13 charges: 3 3 2 5 rmse = 0.45216628715
# NEW BEST 13 charges: 3 3 3 4 rmse = 0.36150678827500005
# NEW BEST 13 charges: 3 3 4 3 rmse = 0.298813669625
# 14 CHARGES:
# NEW BEST 14 charges: 3 2 2 7 rmse = 0.61924060895
# NEW BEST 14 charges: 3 2 3 6 rmse = 0.5309938465749999
# NEW BEST 14 charges: 3 2 4 5 rmse = 0.47320147980000005
# NEW BEST 14 charges: 3 2 5 4 rmse = 0.4606634537
# NEW BEST 14 charges: 3 2 6 3 rmse = 0.444265068075
# NEW BEST 14 charges: 3 3 2 6 rmse = 0.43603983515
# NEW BEST 14 charges: 3 3 3 5 rmse = 0.35829222665000005
# NEW BEST 14 charges: 3 3 4 4 rmse = 0.2875879695
# NEW BEST 14 charges: 3 3 5 3 rmse = 0.2830610819
# NEW BEST 14 charges: 3 4 4 3 rmse = 0.2639902307
# 15 CHARGES:
# NEW BEST 15 charges: 3 2 2 8 rmse = 0.6132089531175
# NEW BEST 15 charges: 3 2 3 7 rmse = 0.52536654845
# NEW BEST 15 charges: 3 2 4 6 rmse = 0.45707502780000003
# NEW BEST 15 charges: 3 2 6 4 rmse = 0.43303936795000003
# NEW BEST 15 charges: 3 2 7 3 rmse = 0.4304424387875
# NEW BEST 15 charges: 3 3 2 7 rmse = 0.430412537025
# NEW BEST 15 charges: 3 3 3 6 rmse = 0.34216577465000003
# NEW BEST 15 charges: 3 3 4 5 rmse = 0.284373407875
# NEW BEST 15 charges: 3 3 5 4 rmse = 0.271835381775
# NEW BEST 15 charges: 3 3 6 3 rmse = 0.25543699615000004
# NEW BEST 15 charges: 3 4 4 4 rmse = 0.252764530575
# NEW BEST 15 charges: 3 4 5 3 rmse = 0.24823764297499998
# NEW BEST 15 charges: 3 5 4 3 rmse = 0.2462753381
# 16 CHARGES:
# NEW BEST 16 charges: 3 2 2 9 rmse = 0.607747945075
# NEW BEST 16 charges: 3 2 3 8 rmse = 0.5193348926175
# NEW BEST 16 charges: 3 2 4 7 rmse = 0.451447729675
# NEW BEST 16 charges: 3 2 5 6 rmse = 0.441322440075
# NEW BEST 16 charges: 3 2 6 5 rmse = 0.42982480632500003
# NEW BEST 16 charges: 3 2 7 4 rmse = 0.41921673866250003
# NEW BEST 16 charges: 3 3 3 7 rmse = 0.336538476525
# NEW BEST 16 charges: 3 3 4 6 rmse = 0.268246955875
# NEW BEST 16 charges: 3 3 6 4 rmse = 0.24421129602500002
# NEW BEST 16 charges: 3 3 7 3 rmse = 0.2416143668625
# NEW BEST 16 charges: 3 4 5 4 rmse = 0.23701194285
# NEW BEST 16 charges: 3 4 6 3 rmse = 0.220613557225
# 17 CHARGES:
# NEW BEST 17 charges: 3 2 2 10 rmse = 0.6039056585
# NEW BEST 17 charges: 3 2 3 9 rmse = 0.5138738845749999
# NEW BEST 17 charges: 3 2 4 8 rmse = 0.44541607384250004
# NEW BEST 17 charges: 3 2 5 7 rmse = 0.43569514195
# NEW BEST 17 charges: 3 2 6 6 rmse = 0.413698354325
# NEW BEST 17 charges: 3 3 3 8 rmse = 0.33050682069250004
# NEW BEST 17 charges: 3 3 4 7 rmse = 0.26261965775
# NEW BEST 17 charges: 3 3 5 6 rmse = 0.25249436815
# NEW BEST 17 charges: 3 3 6 5 rmse = 0.24099673440000002
# NEW BEST 17 charges: 3 3 7 4 rmse = 0.23038866673750003
# NEW BEST 17 charges: 3 4 6 4 rmse = 0.20938785710000002
# NEW BEST 17 charges: 3 4 7 3 rmse = 0.2067909279375
# NEW BEST 17 charges: 3 5 6 3 rmse = 0.202898664625
# 18 CHARGES:
# NEW BEST 18 charges: 3 2 2 11 rmse = 25000.3414487545
# NEW BEST 18 charges: 3 2 3 10 rmse = 0.510031598
# NEW BEST 18 charges: 3 2 4 9 rmse = 0.43995506580000004
# NEW BEST 18 charges: 3 2 5 8 rmse = 0.4296634861175
# NEW BEST 18 charges: 3 2 6 7 rmse = 0.4080710562
# NEW BEST 18 charges: 3 2 7 6 rmse = 0.3998757250375
# NEW BEST 18 charges: 3 3 3 9 rmse = 0.32504581265000004
# NEW BEST 18 charges: 3 3 4 8 rmse = 0.2565880019175
# NEW BEST 18 charges: 3 3 5 7 rmse = 0.24686707002499997
# NEW BEST 18 charges: 3 3 6 6 rmse = 0.2248702824
# NEW BEST 18 charges: 3 4 5 6 rmse = 0.21767092922499998
# NEW BEST 18 charges: 3 4 6 5 rmse = 0.20617329547500002
# NEW BEST 18 charges: 3 4 7 4 rmse = 0.19556522781250002
# NEW BEST 18 charges: 3 5 6 4 rmse = 0.1916729645
# NEW BEST 18 charges: 3 5 7 3 rmse = 0.1890760353375
# 19 CHARGES:
# NEW BEST 19 charges: 3 2 2 12 rmse = 25000.3414487545
# NEW BEST 19 charges: 3 2 3 11 rmse = 25000.247574694
# NEW BEST 19 charges: 3 2 4 10 rmse = 0.436112779225
# NEW BEST 19 charges: 3 2 5 9 rmse = 0.424202478075
# NEW BEST 19 charges: 3 2 6 8 rmse = 0.4020394003675
# NEW BEST 19 charges: 3 2 7 7 rmse = 0.3942484269125
# NEW BEST 19 charges: 3 3 3 10 rmse = 0.321203526075
# NEW BEST 19 charges: 3 3 4 9 rmse = 0.251126993875
# NEW BEST 19 charges: 3 3 5 8 rmse = 0.24083541419249999
# NEW BEST 19 charges: 3 3 6 7 rmse = 0.219242984275
# NEW BEST 19 charges: 3 3 7 6 rmse = 0.2110476531125
# NEW BEST 19 charges: 3 4 6 6 rmse = 0.190046843475
# NEW BEST 19 charges: 3 5 6 5 rmse = 0.188458402875
# NEW BEST 19 charges: 3 5 7 4 rmse = 0.1778503352125
# 20 CHARGES:
# NEW BEST 20 charges: 3 2 3 12 rmse = 25000.247574694
# NEW BEST 20 charges: 3 2 4 11 rmse = 25000.173655875224
# NEW BEST 20 charges: 3 2 5 10 rmse = 0.4203601915
# NEW BEST 20 charges: 3 2 6 9 rmse = 0.39657839232500003
# NEW BEST 20 charges: 3 2 7 8 rmse = 0.38821677108
# NEW BEST 20 charges: 3 3 4 10 rmse = 0.2472847073
# NEW BEST 20 charges: 3 3 5 9 rmse = 0.23537440615
# NEW BEST 20 charges: 3 3 6 8 rmse = 0.21321132844250001
# NEW BEST 20 charges: 3 3 7 7 rmse = 0.2054203549875
# NEW BEST 20 charges: 3 4 6 7 rmse = 0.18441954535
# NEW BEST 20 charges: 3 4 7 6 rmse = 0.1762242141875
# NEW BEST 20 charges: 3 5 6 6 rmse = 0.172331950875
# NEW BEST 20 charges: 3 6 7 4 rmse = 0.16992806523749998
# NEW BEST 20 charges: 4 5 7 4 rmse = 0.1679724928625
# NEW BEST 20 charges: 5 5 7 3 rmse = 0.1664482411625
# 21 CHARGES:
# NEW BEST 21 charges: 3 2 4 12 rmse = 25000.173655875224
# NEW BEST 21 charges: 3 2 5 11 rmse = 25000.1579032875
# NEW BEST 21 charges: 3 2 6 10 rmse = 0.39273610575
# NEW BEST 21 charges: 3 2 7 9 rmse = 0.38275576303750003
# NEW BEST 21 charges: 3 3 5 10 rmse = 0.23153211957499997
# NEW BEST 21 charges: 3 3 6 9 rmse = 0.20775032040000002
# NEW BEST 21 charges: 3 3 7 8 rmse = 0.19938869915500002
# NEW BEST 21 charges: 3 4 6 8 rmse = 0.1783878895175
# NEW BEST 21 charges: 3 4 7 7 rmse = 0.1705969160625
# NEW BEST 21 charges: 3 5 6 7 rmse = 0.16670465275000002
# NEW BEST 21 charges: 3 5 7 6 rmse = 0.1585093215875
# NEW BEST 21 charges: 5 5 7 4 rmse = 0.1552225410375
# 22 CHARGES:
# NEW BEST 22 charges: 3 2 5 12 rmse = 25000.1579032875
# NEW BEST 22 charges: 3 2 6 11 rmse = 25000.13027920175
# NEW BEST 22 charges: 3 2 7 10 rmse = 0.3789134764625
# NEW BEST 22 charges: 3 3 6 10 rmse = 0.203908033825
# NEW BEST 22 charges: 3 3 7 9 rmse = 0.19392769111250002
# NEW BEST 22 charges: 3 4 6 9 rmse = 0.17292688147500002
# NEW BEST 22 charges: 3 4 7 8 rmse = 0.16456526023
# NEW BEST 22 charges: 3 5 6 8 rmse = 0.1606729969175
# NEW BEST 22 charges: 3 5 7 7 rmse = 0.15288202346250002
# NEW BEST 22 charges: 3 6 7 6 rmse = 0.1505870516125
# NEW BEST 22 charges: 4 5 7 6 rmse = 0.14863147923749997
# NEW BEST 22 charges: 5 6 7 4 rmse = 0.1473002710625
# 23 CHARGES:
# NEW BEST 23 charges: 3 2 6 12 rmse = 25000.13027920175
# NEW BEST 23 charges: 3 2 7 11 rmse = 25000.11645657246
# NEW BEST 23 charges: 3 2 8 10 rmse = 0.375459813335
# NEW BEST 23 charges: 3 3 7 10 rmse = 0.1900854045375
# NEW BEST 23 charges: 3 4 6 10 rmse = 0.1690845949
# NEW BEST 23 charges: 3 4 7 9 rmse = 0.15910425218750002
# NEW BEST 23 charges: 3 5 6 9 rmse = 0.155211988875
# NEW BEST 23 charges: 3 5 7 8 rmse = 0.14685036763
# NEW BEST 23 charges: 3 6 7 7 rmse = 0.1449597534875
# NEW BEST 23 charges: 4 5 7 7 rmse = 0.1430041811125
# NEW BEST 23 charges: 4 6 7 6 rmse = 0.1407092092625
# NEW BEST 23 charges: 5 5 7 6 rmse = 0.13588152741249998
# 24 CHARGES:
# NEW BEST 24 charges: 3 2 7 12 rmse = 25000.11645657246
# NEW BEST 24 charges: 3 2 8 11 rmse = 25000.113002909337
# NEW BEST 24 charges: 3 3 6 12 rmse = 24999.941451129824
# NEW BEST 24 charges: 3 3 7 11 rmse = 24999.927628500536
# NEW BEST 24 charges: 3 3 8 10 rmse = 0.18663174141
# NEW BEST 24 charges: 3 4 7 10 rmse = 0.1552619656125
# NEW BEST 24 charges: 3 5 6 10 rmse = 0.1513697023
# NEW BEST 24 charges: 3 5 7 9 rmse = 0.1413893595875
# NEW BEST 24 charges: 3 6 7 8 rmse = 0.138928097655
# NEW BEST 24 charges: 4 5 7 8 rmse = 0.13697252527999998
# NEW BEST 24 charges: 4 6 7 7 rmse = 0.1350819111375
# NEW BEST 24 charges: 5 5 7 7 rmse = 0.1302542292875
# NEW BEST 24 charges: 5 6 7 6 rmse = 0.1279592574375
# 25 CHARGES:
# NEW BEST 25 charges: 3 2 8 12 rmse = 25000.113002909337
# NEW BEST 25 charges: 3 3 7 12 rmse = 24999.927628500536
# NEW BEST 25 charges: 3 3 8 11 rmse = 24999.92417483741
# NEW BEST 25 charges: 3 4 6 12 rmse = 24999.9066276909
# NEW BEST 25 charges: 3 4 7 11 rmse = 24999.892805061612
# NEW BEST 25 charges: 3 4 8 10 rmse = 0.151808302485
# NEW BEST 25 charges: 3 5 7 10 rmse = 0.1375470730125
# NEW BEST 25 charges: 3 6 7 9 rmse = 0.1334670896125
# NEW BEST 25 charges: 4 5 7 9 rmse = 0.1315115172375
# NEW BEST 25 charges: 4 6 7 8 rmse = 0.129050255305
# NEW BEST 25 charges: 5 5 7 8 rmse = 0.124222573455
# NEW BEST 25 charges: 5 6 7 7 rmse = 0.1223319593125
# NEW BEST 25 charges: 7 5 7 6 rmse = 0.1171617259125
# 26 CHARGES:
# NEW BEST 26 charges: 3 3 8 12 rmse = 24999.92417483741
# NEW BEST 26 charges: 3 4 7 12 rmse = 24999.892805061612
# NEW BEST 26 charges: 3 4 8 11 rmse = 24999.889351398484
# NEW BEST 26 charges: 3 5 6 12 rmse = 24999.8889127983
# NEW BEST 26 charges: 3 5 7 11 rmse = 24999.87509016901
# NEW BEST 26 charges: 3 5 8 10 rmse = 0.134093409885
# NEW BEST 26 charges: 3 6 7 10 rmse = 0.12962480303749999
# NEW BEST 26 charges: 4 5 7 10 rmse = 0.1276692306625
# NEW BEST 26 charges: 4 6 7 9 rmse = 0.1235892472625
# NEW BEST 26 charges: 5 5 7 9 rmse = 0.11876156541249999
# NEW BEST 26 charges: 5 6 7 8 rmse = 0.11630030348
# NEW BEST 26 charges: 7 5 7 7 rmse = 0.1115344277875
# NEW BEST 26 charges: 7 6 7 6 rmse = 0.1092394559375
# 27 CHARGES:
# NEW BEST 27 charges: 3 4 8 12 rmse = 24999.889351398484
# NEW BEST 27 charges: 3 5 7 12 rmse = 24999.87509016901
# NEW BEST 27 charges: 3 5 8 11 rmse = 24999.871636505886
# NEW BEST 27 charges: 3 6 7 11 rmse = 24999.867167899036
# NEW BEST 27 charges: 3 6 8 10 rmse = 0.12617113991
# NEW BEST 27 charges: 4 5 8 10 rmse = 0.124215567535
# NEW BEST 27 charges: 4 6 7 10 rmse = 0.1197469606875
# NEW BEST 27 charges: 5 5 7 10 rmse = 0.1149192788375
# NEW BEST 27 charges: 5 6 7 9 rmse = 0.1108392954375
# NEW BEST 27 charges: 7 5 7 8 rmse = 0.105502771955
# NEW BEST 27 charges: 7 6 7 7 rmse = 0.1036121578125
# 28 CHARGES:
# NEW BEST 28 charges: 3 5 8 12 rmse = 24999.871636505886
# NEW BEST 28 charges: 3 6 7 12 rmse = 24999.867167899036
# NEW BEST 28 charges: 3 6 8 11 rmse = 24999.86371423591
# NEW BEST 28 charges: 3 7 8 10 rmse = 0.12665202126
# NEW BEST 28 charges: 3 8 7 10 rmse = 0.12261494642500001
# NEW BEST 28 charges: 4 6 8 10 rmse = 0.11629329756000001
# NEW BEST 28 charges: 5 5 8 10 rmse = 0.11146561571000001
# NEW BEST 28 charges: 5 6 7 10 rmse = 0.1069970088625
# NEW BEST 28 charges: 6 6 7 9 rmse = 0.1069579933375
# NEW BEST 28 charges: 7 5 7 9 rmse = 0.1000417639125
# NEW BEST 28 charges: 7 6 7 8 rmse = 0.09758050198
# 29 CHARGES:
# NEW BEST 29 charges: 3 6 8 12 rmse = 24999.86371423591
# NEW BEST 29 charges: 3 8 7 11 rmse = 24999.860158042426
# NEW BEST 29 charges: 3 8 8 10 rmse = 0.11916128329750002
# NEW BEST 29 charges: 4 7 8 10 rmse = 0.11677417891000001
# NEW BEST 29 charges: 4 8 7 10 rmse = 0.11273710407500001
# NEW BEST 29 charges: 5 6 8 10 rmse = 0.10354334573500001
# NEW BEST 29 charges: 6 6 7 10 rmse = 0.10311570676250001
# NEW BEST 29 charges: 7 5 7 10 rmse = 0.0961994773375
# NEW BEST 29 charges: 7 6 7 9 rmse = 0.09211949393749999
# 30 CHARGES:
# NEW BEST 30 charges: 3 7 8 12 rmse = 24999.86419511726
# NEW BEST 30 charges: 3 8 7 12 rmse = 24999.860158042426
# NEW BEST 30 charges: 3 8 8 11 rmse = 24999.856704379297
# NEW BEST 30 charges: 4 6 8 12 rmse = 24999.85383639356
# NEW BEST 30 charges: 4 8 7 11 rmse = 24999.850280200077
# NEW BEST 30 charges: 4 8 8 10 rmse = 0.10928344094750002
# NEW BEST 30 charges: 5 7 8 10 rmse = 0.104024227085
# NEW BEST 30 charges: 5 8 7 10 rmse = 0.09998715225
# NEW BEST 30 charges: 6 6 8 10 rmse = 0.09966204363500002
# NEW BEST 30 charges: 7 5 8 10 rmse = 0.09274581421
# NEW BEST 30 charges: 7 6 7 10 rmse = 0.0882772073625
# 31 CHARGES:
# NEW BEST 31 charges: 3 8 8 12 rmse = 24999.856704379297
# NEW BEST 31 charges: 4 7 8 12 rmse = 24999.85431727491
# NEW BEST 31 charges: 4 8 7 12 rmse = 24999.850280200077
# NEW BEST 31 charges: 4 8 8 11 rmse = 24999.84682653695
# NEW BEST 31 charges: 5 6 8 12 rmse = 24999.841086441735
# NEW BEST 31 charges: 5 8 7 11 rmse = 24999.83753024825
# NEW BEST 31 charges: 5 8 8 10 rmse = 0.09653348912250001
# NEW BEST 31 charges: 6 8 7 10 rmse = 0.09610585015
# NEW BEST 31 charges: 7 6 8 10 rmse = 0.084823544235
# NEW BEST 31 charges: 9 6 7 9 rmse = 0.084286486165
# 32 CHARGES:
# NEW BEST 32 charges: 4 8 8 12 rmse = 24999.84682653695
# NEW BEST 32 charges: 5 7 8 12 rmse = 24999.841567323085
# NEW BEST 32 charges: 5 8 7 12 rmse = 24999.83753024825
# NEW BEST 32 charges: 5 8 8 11 rmse = 24999.83407658512
# NEW BEST 32 charges: 6 8 7 11 rmse = 24999.83364894615
# NEW BEST 32 charges: 6 8 8 10 rmse = 0.09265218702250001
# NEW BEST 32 charges: 7 7 8 10 rmse = 0.08530442558500001
# NEW BEST 32 charges: 7 8 7 10 rmse = 0.08126735075000001
# NEW BEST 32 charges: 9 6 7 10 rmse = 0.08044419959
# 33 CHARGES:
# NEW BEST 33 charges: 5 8 8 12 rmse = 24999.83407658512
# NEW BEST 33 charges: 6 8 7 12 rmse = 24999.83364894615
# NEW BEST 33 charges: 6 8 8 11 rmse = 24999.830195283022
# NEW BEST 33 charges: 7 6 8 12 rmse = 24999.822366640234
# NEW BEST 33 charges: 7 8 7 11 rmse = 24999.81881044675
# NEW BEST 33 charges: 7 8 8 10 rmse = 0.0778136876225
# NEW BEST 33 charges: 9 6 8 10 rmse = 0.07699053646250001
# 34 CHARGES:
# NEW BEST 34 charges: 6 8 8 12 rmse = 24999.830195283022
# NEW BEST 34 charges: 7 7 8 12 rmse = 24999.822847521584
# NEW BEST 34 charges: 7 8 7 12 rmse = 24999.81881044675
# NEW BEST 34 charges: 7 8 8 11 rmse = 24999.815356783623
# NEW BEST 34 charges: 8 8 8 10 rmse = 0.07681998574000001
# NEW BEST 34 charges: 9 8 7 10 rmse = 0.0734343429775
# 35 CHARGES:
# NEW BEST 35 charges: 7 8 8 12 rmse = 24999.815356783623
# NEW BEST 35 charges: 8 8 8 11 rmse = 24999.81436308174
# NEW BEST 35 charges: 9 8 7 11 rmse = 24999.810977438978
# NEW BEST 35 charges: 9 8 8 10 rmse = 0.06998067985
# 36 CHARGES:
# NEW BEST 36 charges: 8 8 8 12 rmse = 24999.81436308174
# NEW BEST 36 charges: 9 8 7 12 rmse = 24999.810977438978
# NEW BEST 36 charges: 9 8 8 11 rmse = 24999.80752377585
# NEW BEST 36 charges: 10 8 8 10 rmse = 24999.801862930526
# 37 CHARGES:
# NEW BEST 37 charges: 9 8 8 12 rmse = 24999.80752377585
# NEW BEST 37 charges: 11 8 8 10 rmse = 24999.801862930526
# 38 CHARGES:
# NEW BEST 38 charges: 10 8 8 12 rmse = 49999.539406026524
# NEW BEST 38 charges: 12 8 8 10 rmse = 24999.801862930526
# 39 CHARGES:
# NEW BEST 39 charges: 11 8 8 12 rmse = 49999.539406026524
# 40 CHARGES:
# NEW BEST 40 charges: 12 8 8 12 rmse = 49999.539406026524

# %%
pydcm.refine_models()
# Out:
# Job 3484534 has crashed, resubmitting
# submitted jobID 3484667
# Job 3484535 has crashed, resubmitting
# submitted jobID 3484668
# Job 3484536 has crashed, resubmitting
# submitted jobID 3484669
# Job 3484537 has crashed, resubmitting
# submitted jobID 3484670
# Job 3484538 has crashed, resubmitting
# submitted jobID 3484671
# Job 3484539 has crashed, resubmitting
# submitted jobID 3484672
# Job 3484540 has crashed, resubmitting
# submitted jobID 3484673
#
# Summary of results:
# 10 charges, RMSE: 0.6399519403 kcal/mol
# 11 charges, RMSE: 0.6053116336 kcal/mol
# 12 charges, RMSE: 0.5917268748 kcal/mol
# 13 charges, RMSE: 0.5393169763 kcal/mol
# 14 charges, RMSE: 0.5310510401 kcal/mol
# 15 charges, RMSE: 0.5303452465 kcal/mol
# 16 charges, RMSE: 0.5024957357 kcal/mol
# 17 charges, RMSE: 0.5026437935 kcal/mol
# 18 charges, RMSE: 0.4987985574 kcal/mol
# 19 charges, RMSE: 0.4987885603 kcal/mol
# 20 charges, RMSE: 0.4914891799 kcal/mol
# 21 charges, RMSE: 0.4916420179 kcal/mol
# 22 charges, RMSE: 0.4851304963 kcal/mol
# 23 charges, RMSE: 0.4854859805 kcal/mol
# 24 charges, RMSE: 0.4799289585 kcal/mol
# 25 charges, RMSE: 0.4867274325 kcal/mol
# 26 charges, RMSE: 0.4813565076 kcal/mol
# 27 charges, RMSE: 0.4816773749 kcal/mol
# 28 charges, RMSE: 0.4809913652 kcal/mol
# 29 charges, RMSE: 0.4794953879 kcal/mol
# 30 charges, RMSE: 0.4790957592 kcal/mol
# 31 charges, RMSE: 0.4791986632 kcal/mol
# 32 charges, RMSE: 0.4781125845 kcal/mol
# 33 charges, RMSE: 0.4780668542 kcal/mol
